# %% [markdown]
# ---
# format:
#     html:
#         embed-resources: true
# ---

# %% [markdown]
# # Crawling

# %% [markdown]
# ## Overview
#
# In this portion of the homework, you will be crawling google jobs to collect various job-descriptions for later processing.
#
# We will be using the `serpapi` API to crawl google jobs. `serpapi` is a paid API, but they have a free tier which should be more than enough for this homework. The API allows you to search google programatically, which has a wealth of practical applications.

# %% [markdown]
# You will need and API key from SerpApi, it is free to sign up, you shouldn't enter any payment information.
#
# https://serpapi.com/manage-api-key
#
# This will get you 100 free searches per month. Each search will get you 10 job-descriptions, for a total of around 1000 possible job-descriptions per month.
#
# This portion of the homework relies on limited API search resources, so prototype carefully, once you are sure it is working 100%, then you should run it one last time.
#
# Consider reserving about 10 searches for prototyping, with the remaining 90 searches for your final "production" run.
#
# Make sure to save the outputs, and have them backed up after this final run, in case you delete them by mistake.
#
# We will use the following python wrapper for the API, it can be installed with
#
# `pip install google-search-results`

# %% [markdown]
# The following are additional useful reference resources
#
# For instructions on the API see the following
#
# * [https://serpapi.com/google-jobs-api](https://serpapi.com/google-jobs-api)
# * [https://serpapi.com/blog/scrape-google-jobs-organic-results-with-python/](https://serpapi.com/blog/scrape-google-jobs-organic-results-with-python/)
# * [https://serpapi.com/integrations/python](https://serpapi.com/integrations/python)

# %% [markdown]
# ## Starter code
#
# Here is some starter code:

# %% [markdown]
# `Note: uule parameter`
#
# The uule parameter is an encoded location parameter used in Google search queries. It stands for "Unique User Location Encoding" and is used to specify the geographic location from which the search is being conducted. This can influence the search results to be more relevant to the specified location.
#
# This can be set to `'w+CAIQICINVW5pdGVkIFN0YXRlcw'`, which is an encoded string representing a specific location, i.e. the United States. This encoding helps simulate searches as if they are being conducted from that location, which can be useful for testing or gathering location-specific data.

# %%
from serpapi import GoogleSearch
import json

# %% [markdown]
# Save your API key in a centralized location, e.g. `~/.api-keys.json`
#
# Read it in with `import json`

# %%
import json
with open('/Users/zp/Desktop/api-key.json') as f:
    keys = json.load(f)
API_KEY = keys['serpapi']

# %% [markdown]
# Be careful, don't run this too many times for debugging and prototyping, or you will use up all your free searches.

# %%
search_query = 'data science'
params = {
	'api_key':API_KEY,                          # https://serpapi.com/manage-api-key
	'uule': 'w+CAIQICINVW5pdGVkIFN0YXRlcw',		# encoded location (USA)
	'q': search_query,              			# search query
    'hl': 'en',                         		# language of the search
    'gl': 'us',                         		# country of the search
	'engine': 'google_jobs',					# SerpApi search engine
}

# %% [markdown]
# Lets do one search and explore the output

# %%
search = GoogleSearch(params)   			# where data extraction happens on the SerpApi backend
result_dict = search.get_dict() 			# JSON -> Python dict

if 'error' in result_dict:
    print("ERROR FOUND IN SEARCH")

# %%
for result in result_dict['jobs_results']:
    print(result)
    # google_jobs_results.append(result)
# Out:
# {'title': 'AVP, Data Science - Underwriting and Operations Analytics | Hartford, WI, USA', 'company_name': 'The Travelers Indemnity Company', 'location': 'Hartford, WI', 'via': 'EFinancialCareers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=3idjrGTlPG2bZbk3AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=3idjrGTlPG2bZbk3AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa7d885388f748141ba8257bfd16e379fa3e64fc0cf0bc18251.jpeg', 'extensions': ['21 hours ago', 'Full-time', 'Paid time off', 'Health insurance'], 'detected_extensions': {'posted_at': '21 hours ago', 'schedule_type': 'Full-time', 'paid_time_off': True, 'health_insurance': True}, 'description': "AVP, Data Science - Underwriting and Operations Analytics\n\nWho Are We?\n\nTaking care of our customers, our communities and each other. That's the Travelers Promise. By honoring this commitment, we have maintained our reputation as one of the best property casualty insurers in the industry for over 160 years. Join us to discover a culture that is rooted in innovation and thrives on collaboration. Imagine loving what you do and where you do it.\n\nJob Category\n\nData Science\n\nCompensation Overview\n\nThe annual base salary range provided for this position is a nationwide market range and represents a broad range of salaries for this role across the country. The actual salary for this position will be determined by a number of factors, including the scope, complexity and location of the role; the skills, education, training, credentials and experience of the candidate; and other conditions of employment. As part of our comprehensive compensation and benefits program, employees are also eligible for performance-based cash incentive awards.\n\nSalary Range\n$181,800.00 - $300,000.00\n\nTarget Openings\n\n1\n\nWhat Is the Opportunity?\n\nIn Business Insurance Actuarial & Analytics, we deliver tailored analytics and innovative data science solutions that influence decisions and enable superior results. We have an inclusive culture where everyone feels that they belong, can be authentic, are valued, respected, empowered and part of our success. We see strength in the uniqueness that each of us contributes to creating innovative solutions and improving business outcomes.\n\nTravelers Data Scientists are taking the organization to the next level of intelligence by using advanced statistical techniques and machine learning algorithms. As the Underwriting and Operations Lead, you will lead a team of 4 data scientists responsible for creating and championing machine learning/AI solutions for use by underwriters and operations personnel. These solutions are aimed at increasing their effectiveness, reducing their turn around times and eliminating friction. You will also collaborate with both business and technology partners to drive analytics out to our products in the marketplace, giving Travelers a competitive advantage. What Will You Do?\n\n• Present analysis, insights, results, and recommendations to executives for decisions in the UW and Ops space.\n• Anticipate potential objections and influence executives to adopt a different point of view.\n• Take ownership of the UW and Ops portfolio of projects making recommendations that influence business outcomes.\n• Drive teams and leaders to ensure the successful execution of data science strategies.\n• Start identifying organizational tension and work to build consensus across the organization. Assist in the development of business plans for the portfolio.\n• Influence outcomes in the line of business and/or data science community through discussions, presentations, or peer reviews.\n• Drive team recruiting, training, and talent assessment efforts.\n• Provide guidance and coaching for team members; guide your team to advance their subject matter expertise and to identify future leaders  ...
# {'title': 'AIML-Principal Data Scientist, Measurements', 'company_name': 'Apple', 'location': 'Cupertino, CA', 'via': 'Careers At Apple', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=01NjAzLkTuD4AKMDAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=01NjAzLkTuD4AKMDAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa79c7f032dce1458b30e50ee459cf1642770586f89cad56f59.png', 'extensions': ['3 days ago', 'Full-time', 'Health insurance', 'Dental insurance'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full-time', 'health_insurance': True, 'dental_coverage': True}, 'description': "Summary\nPosted: Nov 1, 2024\nWeekly Hours: 40\nRole Number:200575618\n\nImagine what you could do here. At Apple, new ideas have a way of becoming great products, services, and customer experiences very quickly. Bring passion and dedication to your job and there's no telling what you could accomplish. The Measurement org works with teams across Apple to build platforms, create methodologies, and enable partners to measure, understand, and proactively improve their products. We are looking for an outstanding candidate to become a member of the Measurement team and help own and drive part of our technical portfolio for Apple Intelligence.\n\nDescription\n\nDescription\nWe are seeking an experienced engineer, applied ML practitioner or data scientist to own several highly visible initiatives in the Measurement team of Apple's artificial intelligence\n\nIN THIS ROLE YOU WILL:\n- Partner with several engineering groups to build tooling, processes, and methodologies to automatically understand and improve Apple products and services\n\n- Engage in research on the development of data collection systems that enable training and evaluation of generative AI systems while preserving privacy.\n\n- Partner with the head of the Measurement org to drive several research projects and prototype applications to gauge appropriateness for larger investment\n\n- Use LLMs to optimize resource allocation and measure the quality of generative AI models, products, and services.\n\nSuccessful candidates will need to have a passion for user privacy and superb communication skills with an ability to influence at all levels of the organization, from junior engineers to Sr. Directors and SVPs. Creative problem solving, analytical, and deductive reasoning skills are critical for this position. You will be working on multiple unrelated systems each week, so the ability to learn quickly and an excitement for new things is a must. You must be comfortable with ambiguity and a complex cross-functional environment, requiring relentless collaboration and laser focus on outcomes.\n\nMinimum Qualifications\n\nMinimum Qualifications\n• Experience leading strategic technical projects with multiple stakeholders and directing work of other engineers and/or data scientists or as a technical lead\n• Strong collaboration, communication, interpersonal, and organizational skills\n• Ability to solve complex problems independently\n• Experience with foundation models, including training and evaluation\n• Programming experience\n\nKey Qualifications\n\nKey Qualifications\n\nPreferred Qualifications\n\nPreferred Qualifications\n• Passion for customer privacy\n• Ph D in Statistics, Biostatistics, Computer Science, Machine Learning, or equivalent experience\n\nEducation & Experience\n\nEducation & Experience\n\nAdditional Requirements\n\nAdditional Requirements\n\nPay & Benefits\n\nPay & Benefits\n• At Apple, base pay is one part of our total compensation package and is determined within a range. This provides the opportunity to progress as you grow and develop within a role. The base pay range for this role is between $207,800 and $378,700, and your base pay will depend on your skills, qualifications, experience, and location.\n\nApple e ...
# {'title': 'Data Scientist', 'company_name': 'U.S. Army Cyber Command', 'location': 'Chico, CA', 'via': 'LinkedIn', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=tpkaGB2OmX_412WXAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=tpkaGB2OmX_412WXAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa7b390d7618592da8e4c881ed38999483167f9b0890e8934af.jpeg', 'extensions': ['2 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '2 days ago', 'schedule_type': 'Full-time'}, 'description': 'Major Duties\n• Serves as a Senior Data Scientist leading teams for the most complex projects. May also serve as a team participant or an independent analyst on professional data science teams.\n• Applies the rigors of the data science discipline to data analysis in Cyber, Information Technology and economic analyses of complex and potentially controversial major information technology systems and networks.\n• Responsible for advanced level data science analytics characterized as highly unstructured and complex, having little definition or clarity, and especially complex analytic projects assigned to the organization.\n• Provides business metrics and support for the most complex projects to identify improvements (contribution to the improvement should be monitored initially and over multiple iterations).\n• Coordinates with the data steward to ensure that the information used follows the regulatory and security policies in place.\n• Qualify where information can be stored or what information, external to the organization, may be used in support of the use case.\n• Lead analytical projects, providing direction and guidance to project members of a professional nature in the execution and implementation of projects.\n\nQualifications/ Specialized Experience\n\nWho May Apply: Only applicants who meet one of the employment authority categories below are eligible to apply for this job. You will be asked to identify which category or categories you meet, and to provide documents which prove you meet the category or categories you selected. See Proof of Eligibility for an extensive list of document requirements for all employment authorities. Current Army Cyber Excepted Service (CES) Employee Current Army Defense Civilian Intelligence Personnel System (DCIPS) Employee Current Civilian Employees of the Organization Applying to Cyber Excepted Service (CES) Positions Current Department of Army Civilian Employees Current DoD Cyber Excepted Service (CES) Employee (non-Army) Current DoD Defense Civilian Intelligence Personnel System (DCIPS) Employee (non-Army) Current Permanent DoD Civilian Employee (non-Army) Applying to Cyber Excepted Service Positions Non-Department of Defense (DoD) Transfer Applying to Cyber Excepted Service Positions Army CES positions apply Veteran\'s Preference to preference eligible candidates, as defined by Section 2108 of Title 5 U.S.C., in accordance with the procedures provided in DoD Instruction 1400.25, Volume 3005, "CES Employment and Placement". If you are a veteran claiming veterans\' preference, as defined by Section 2108 of Title 5 U.S.C., you must submit documents verifying your eligibility with your application package. In order to qualify, you must meet the education and experience requirements described below. Experience refers to paid and unpaid experience, including volunteer work done through National Service programs (e.g., Peace Corps, AmeriCorps) and other organizations (e.g., professional; philanthropic; religious; spiritual; community; student; social). You will receive credit for all qualifying experience, including volunteer experience. Your resume must clearly describe your relevant experience; if qualifying based on education, your transcripts will be required as part of your application. Additional information about transcripts is in this document. Basic Req ...
# {'title': 'Intern Data Science AI&I - PHD (On-site)', 'company_name': 'Mayo Clinic', 'location': 'Rochester, MN', 'via': 'Mayo Clinic Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=yR0hQNEpSKswbeZYAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=yR0hQNEpSKswbeZYAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa7d4c700258c5817eb0a2b88cafc9d3be83d6656a33d0ccdfa.png', 'extensions': ['18 days ago', 'Full-time and Internship'], 'detected_extensions': {'posted_at': '18 days ago', 'schedule_type': 'Full-time and Internship'}, 'description': 'Why Mayo Clinic\n\nMayo Clinic is top-ranked in more specialties than any other care provider according to U.S. News & World Report. As we work together to put the needs of the patient first, we are also dedicated to our employees, investing in competitive compensation and comprehensive benefit plans – to take care of you and your family, now and in the future. And with continuing education and advancement opportunities at every turn, you can build a long, successful career with Mayo Clinic. You’ll thrive in an environment that supports innovation, is committed to ending racism and supporting diversity, equity and inclusion, and provides the resources you need to succeed.\n\nResponsibilities\n\nFunctions as an artificial intelligence and informatics researcher by applying data science, artificial intelligence and informatics, and machine learning expertise to the design, implementation, analysis, interpretations, and reporting of research, clinical and administrative studies.\n\nNote: This is a temporary role. The goal is a January 2025 start (through April 2025 with the possibility of extension).\n\nQualifications\n\nWorking towards a PhD degree in data science, computer science, mathematics/statistics, informatics, computer engineering, or related field.\n\nExcellent Python skills needed. Research experience in artificial intelligence, machine learning, data science or related field preferred.\n\nMust have excellent analytical and problem-solving expertise, along with exceptional written and oral communication skills.\n\nMust be highly motived, willing to learn, and demonstrate initiative in assigned tasks.\n\nExemption Status\n\nNonexempt\n\nCompensation Detail\n\nThis position has a predetermined rate of $27.76 per hour.\n\nBenefits Eligible\n\nNo\n\nSchedule\n\nFull Time\n\nHours/Pay Period\n\n80\n\nSchedule Details\n\nM-F 8am-5pm; The goal is a January start through April 2025 with the possibility of extension.\n\nWeekend Schedule\n\nN/A\n\nInternational Assignment\n\nNo\n\nSite Description\n\nJust as our reputation has spread beyond our Minnesota roots, so have our locations. Today, our employees are located at our three major campuses in Phoenix/Scottsdale, Arizona, Jacksonville, Florida, Rochester, Minnesota, and at Mayo Clinic Health System campuses throughout Midwestern communities, and at our international locations. Each Mayo Clinic location is a special place where our employees thrive in both their work and personal lives. Learn more about what each unique Mayo Clinic campus has to offer, and where your best fit is.\n\nAffirmative Action and Equal Opportunity Employer\n\nAs an Affirmative Action and Equal Opportunity Employer Mayo Clinic is committed to creating an inclusive environment that values the diversity of its employees and does not discriminate against any employee or candidate. Women, minorities, veterans, people from the LGBTQ communities and people with disabilities are strongly encouraged to apply to join our teams. Reasonable accommodations to access job openings or to apply for a job are available.\n\nRecruiter\n\nStephanie Baird', 'job_highlights': [{'title': 'Qualifications', 'items': ['Working towards a PhD degree in data science, computer science, mathematics/statistics, informatics, computer engineerin ...
# {'title': 'Data Scientist', 'company_name': 'Elevance Health', 'location': 'Seven Fields, PA', 'via': 'Elevance Health', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=opULy3mENHQ7uD_nAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=opULy3mENHQ7uD_nAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa703e028adf00659d481c19f640f94053f01e756ba2c531c88.jpeg', 'extensions': ['12 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '12 days ago', 'schedule_type': 'Full-time'}, 'description': 'Data Scientist\n\nLocation: This position will work a hybrid model (remote and office). Ideal candidates will live within 50 miles of the following PulsePoint location. 300 Seven Fields Blvd, Suite 100, Seven Fields, PA 16046\n\nHours: Monday to Friday, 8:00 am to 5:00 pm\n\nThe Data Scientist will develop and implement predictive model algorithms and techniques with moderate complexity.\n\nHow you will make an impact:\n\n• Execute algorithms to address specific business problems under the direction of the team lead or manager.\n• Work with data sets of moderate size and complexity.\n• Develop visualization of analysis output for business users and publish results under the direction of team lead or manager.\n• Predict model and machine learning concepts in distributed computing environment.\n• Implement batch and real-time model scoring to drive actions.\n• Provide high-level controllership/evaluation of all output produced to ensure established targets are met.\n• Determine the continuous improvement opportunities of current predictive modeling algorithms.\n• Proactively collaborate with business partners to determine identified population segments and develop actionable plans to enable the identification of patterns related to quality, use, cost and other variables.\nREF#739308\n\nMinimum Requirements:\n\nBachelor’s degree in Statistics, Computer Science, Mathematics, Machine Learning, Econometrics, Physics, Biostatistics or a related field. Three (3) years of experience working in related occupation(s).\n\nAdditional Requirements:\n\nThree (3) years of experience must include:\n\n• Three (3) years of experience with Python, R and SAS.\n• Three (3) years of working experience with Hadoop distributed computing environment.\n• Three (3) years of experience using Hive, Impala, or Apache Spark.\n• Three (3) years of data extraction and manipulation experience using SQL.\n• Three (3) years of experience connecting Tableau or Shiny reports to Hadoop back end.\n• Three (3) years of experience with JavaScript visualization libraries including D3.js.\n\nALTERNATE EDUCATION/EXPERIENCE REQUIREMENTS: Employer will accept a Master’s degree in Statistics, Computer Science, Mathematics, Machine Learning, Econometrics, Physics, Biostatistics or a related field plus one (1) year of experience. Must have one (1) year of experience in each of the skills listed above.', 'job_highlights': [{'title': 'Qualifications', 'items': ['Bachelor’s degree in Statistics, Computer Science, Mathematics, Machine Learning, Econometrics, Physics, Biostatistics or a related field', 'Three (3) years of experience working in related occupation(s)', 'Three (3) years of experience must include:', 'Three (3) years of experience with Python, R and SAS', 'Three (3) years of working experience with Hadoop distributed computing environment', 'Three (3) years of experience using Hive, Impala, or Apache Spark', 'Three (3) years of data extraction and manipulation experience using SQL', 'Three (3) years of experience connecting Tableau or Shiny reports to Hadoop back end', 'Three (3) years of experience with JavaScript visualization libraries including D3.js', 'ALTERNATE EDUCATION/EXPERIENCE REQUIREMENTS: Employer will accept a Master’s degree in Statistics, Computer Science, Mathematics, Machine Learning, Econometrics, Physics, Biost ...
# {'title': 'Staff Data Scientist', 'company_name': 'Abbott Laboratories', 'location': 'Alameda, CA', 'via': 'Abbott Jobs', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=uHSzA8f3zpZj1FqnAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=uHSzA8f3zpZj1FqnAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa72dcf72e4e4ff88752f05238753ae57f27fbf591ee0d6ddcf.png', 'extensions': ['4 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '4 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "Abbott is a global healthcare leader that helps people live more fully at all stages of life. Our portfolio of life-changing technologies spans the spectrum of healthcare, with leading businesses and products in diagnostics, medical devices, nutritionals and branded generic medicines. Our 114,000 colleagues serve people in more than 160 countries.\n\nWorking at Abbott\n\nAt Abbott, you can do work that matters, grow, and learn, care for yourself and family, be your true self and live a full life. You’ll also have access to:\n\n· Career development with an international company where you can grow the career you dream of.\n\n· Free medical coverage for employees* via the Health Investment Plan (HIP) PPO\n\n· An excellent retirement savings plan with high employer contribution\n\n· Tuition reimbursement, the Freedom 2 Save student debt program and FreeU education benefit - an affordable and convenient path to getting a bachelor’s degree.\n\n· A company recognized as a great place to work in dozens of countries around the world and named one of the most admired companies in the world by Fortune.\n\n· A company that is recognized as one of the best big companies to work for as well as a best place to work for diversity, working mothers, female executives, and scientists.\n\nThe Opportunity\n\nStaff Data Scientist works as integral part of a collaborative data and analytics team and responsible for analyzing real-world data to generate insights and develop machine learning models that drive the development and optimization of devices in Abbott Diabetes Care. The role requires drawing insights, and presenting results in a cohesive, intuitive, and simple manner to the functional stakeholders utilizing technologies to collect, clean, analyze, predict, and effectively communicate insights. Key functional stakeholders include research & development, clinical, medical, regulatory and market access teams.\n\nWhat You'll Work On\n• Analyze large real-world datasets including device data, electronic health records (EHR), claims data, labs, and patient registries.\n• Support the design and execution of RWE studies including but not limited to:\n• Treatment optimization and understanding treatment patterns\n• Comparative effectiveness analyses\n• Drug and device utilization\n• Natural history and burden of disease\n• Healthcare resource utilization\n• Analyze data, draw insights, and present results in a cohesive, intuitive, and simple manner to functional stakeholder.\n• Utilize technologies to collect, clean, analyze, predict, and effectively communicate insights such as model logic and restrictions.\n• Conduct advanced statistical analysis to determine trends and significant data relationships.\n• Develop machine learning models to apply test data algorithms to future data.\n• Validate models/analytical techniques and develop algorithms to execute analytical functions.\n• Collaborate with clinical, medical, regulatory, and market access teams to integrate RWE into product development and lifecycle management.\n• Work closely with the functional stakeholders to understand the domain and iteratively refine analyses.\n• Provide learning and educational pathways for team members.\n• Provides input into developing departmental and site processes and procedures.\n• ...
# {'title': 'Junior Data Scientist', 'company_name': 'SynergisticIT', 'location': 'Idaho City, ID', 'via': 'Lensa', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=ODU4hyVyE1BZ9GnDAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=ODU4hyVyE1BZ9GnDAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa7978e85abc11aca743457aea1ac08de19693bf0afee50de40.jpeg', 'extensions': ['2 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '2 days ago', 'schedule_type': 'Full-time'}, 'description': "Since 2010 SynergisticIT has helped Jobseekers get employed in the tech Job market by providing candidates the requisite skills, experience and technical competence to outperform at interviews and at clients.\nThe Tech Job market has been affected by massive layoffs and since 2021 there have been more than 600,000.00 tech layoffs.\nThe Job market is Hyper Competitive. For 1 position 500-1000 candidates or more are applying and laid off job seekers are also competing for entry level Job positions.\n\nPlease see the below links to know more about Synergisticit and some useful tips\n\nhttps://www.synergisticit.com/candidate-outcomes/\nWhy do Tech Companies not Hire recent Computer Science Graduates | SynergisticIT\nTechnical Skills or Experience? | Which one is important to get a Job? | SynergisticIT\n\nWe regularly interact with the Top Tech companies to give our candidates a competitive advantage.\nWe at Synergisticit understand the problem of the mismatch between employer's requirements and Employee skills and that's why since 2010 we have helped 1000's of candidates get jobs at technology clients like apple, google, Paypal, western union, Client, visa, walmart labs etc to name a few.\nWe are continuously looking for entry-level software programmers, Java Full stack developers, Python/Java developers, Data analysts/ Data Scientists, Data Engineers, Machine Learning engineers for full time positions with clients.\n\nWho Should Apply? Recent Computer science/Engineering /Mathematics/Statistics or Science Graduates or People looking to switch careers or who have had gaps in employment and looking to make their careers in the Tech Industry.\nWe need Data Science/Machine learning/Data Analyst and Java Full stack candidates\n\nPreferred SKILLS For Java /Full stack/Devops Positions\nBachelors degree or Masters degree in Computer Science, Computer Engineering, Electrical Engineering, Information Systems, IT\nKnowledge of Core Java , javascript , C++ or software programming\nSpring boot, Microservices, Docker, Jenkins, Github, Kubernates and REST API's experience\nFor data Science/Data Analyst/AI/Machine learning Positions\nPreferred SKILLS\nAssociate or Bachelors degree or Masters degree in Computer Science, Computer Engineering, Electrical Engineering, Information Systems, IT, Statistics, Mathematics or having good logical aptitude\nKnowledge of Statistics, Gen AI, LLM, Sagemaker, Python, Computer Vision, data visualization tools\nCandidates lacking technical skills can research our other programs which can assist in landing a Job\nIf you get emails from our Job Placement team and are not interested please email them or ask them to take you off their distribution list and make you unavailable as they share the same database with the client servicing team who only connect with candidates who are matching client requirements.\nNo phone calls please. Shortlisted candidates would be reached out. No third party or agency candidates or c2c candidates.", 'job_highlights': [{'title': 'Qualifications', 'items': ['Recent Computer science/Engineering /Mathematics/Statistics or Science Graduates or People looking to switch careers or who have had gaps in employment and looking to make their careers in the Tech Industry', 'We need Data Science/Machine learning/Data Analyst and Java Full stack candidates', 'Bachelors  ...
# {'title': 'Sr. Data Scientist', 'company_name': 'Thomson Reuters', 'location': 'McLean, VA', 'via': 'Thomson Reuters Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=6o4mIZnIwDNkNc9oAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=6o4mIZnIwDNkNc9oAAAAAA%3D%3D', 'extensions': ['13 days ago', 'Full-time', 'Dental insurance', 'Paid time off', 'Health insurance'], 'detected_extensions': {'posted_at': '13 days ago', 'schedule_type': 'Full-time', 'dental_coverage': True, 'paid_time_off': True, 'health_insurance': True}, 'description': "Location: Hybrid 2-3x per week in Boston, MA\n\nAre you passionate about the chance to bring your data science experience to a world class organization that is leading the way in both content and technology to serve and protect our citizens home and abroad? Do you have the skills necessary to manage, understand, and analyze in-house and customer data including text mining, developing predictive systems, risk scoring, creating efficient algorithms, data quality improvement and other related activities? Then Thomson Reuters Special Services (TRSS) is looking for you!\n\nAbout the Role\n\nAs a Data Scientist, you will be responsible for driving, identify, evaluate, design and implement statistical analyses of gathered open source, proprietary, and customer data to create analytic metrics and tools to support TRSS analysts, customers and existing product offerings. Successful candidates will have the opportunity to contribute directly to the features and capabilities deployed in our applications. They will work with customers to assist in gathering requirements and contributing to Statements of Work (SOWs) for new sales or POCs, and executing design post sale while getting deeply involved into the delivery of the proposed solutions. The role will interface with the customer and provide continuity of technical and data-exploration expertise to ensure we are delivering a workable solution that meets the customer requirements and technical capabilities. The position requires a proactive, mission-oriented person who strives to produce the best possible work for the customer.\n\nAs the Data Scientist, you will also contribute to a variety of areas including:\n• Working with interdisciplinary engineering and research teams on designing, building and deploying data analysis systems for large data sets.\n• Working closely with customers to apply data science to their mission specific content.\n• Creating algorithms to extract information from large data sets.\n• Establishment of scalable, efficient, automated processes for model development, model validation, model implementation, and large-scale data analysis.\n• Development of metrics and prototypes that can be used to drive business decisions.\n• Providing thought-leadership and dependable execution on diverse projects.\n• Identification of emergent trends and opportunities for future client growth and development.\n• Researching and identifying Artificial Intelligence (AI) methods – including Machine Learning (ML) and Natural Language Processing (NLP) methods.\n• Identification of new applications of AI in the context of Thomson Reuters and TRSS content sets.\n• Exploring existing data for insights, and recommends additional sources of data for improvement.\n\nAbout You\n\nYou’re a good fit for the role of Data Scientist if you have:\n• A Bachelor’s degree in a quantitative field or equivalent experience (e.g., statistics, computer science, mathematics, physical/biological sciences, or GIS).\n• 7-10 years of experience with data cleaning, analysis, programming, and reporting of results to internal or external stakeholders\n• Programming skills in one or more major programming languages (Python/R/Java).\n• Are creative, intellectually curious, and willing to experiment and work in dynamic organizations and situations, sometimes with little oversight or well ...
# {'title': 'Data Scientist/Statistician Intern Summer 2025 (MS/PhD)', 'company_name': 'Lubrizol Corporation', 'location': 'Wickliffe, OH', 'via': 'Lubrizol - The Lubrizol Corporation', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=CNDCGhQEr-8ACYa-AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=CNDCGhQEr-8ACYa-AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/672859379fd309ef4b4fbdde/images/38d82cd27cffaaa7499245360652a431d26e501e33425ca587323a747cf64552.png', 'extensions': ['11 days ago', 'Internship'], 'detected_extensions': {'posted_at': '11 days ago', 'schedule_type': 'Internship'}, 'description': "The Lubrizol Corporation, a Berkshire Hathaway company, is a specialty chemical company whose science delivers sustainable solutions to advance mobility, improve wellbeing and enhance modern life. Founded in 1928, Lubrizol owns and operates more than 100 manufacturing facilities, sales, and technical offices around the world and has about 8,000 employees. For more information, visit www.Lubrizol.com.\n\nWe value diversity in professional backgrounds and life experiences. By enabling a consistent, unbiased, and transparent recruitment process, Lubrizol seeks to create a positive experience for candidates so we can get to know them at their best. We recognize unique work and life situations and offer flexibility, ensuring our employees feel engaged and fulfilled in every aspect of life.\n\nJoin Our Thriving Team at Lubrizol as a Data Scientist/Statistician Intern (MS/PhD)\n\nUnleash Your Potential. At Lubrizol we're transforming the chemical industry and looking for exceptional talent to join us on this journey. If you are ready to join an international company with talent around the world, and want to make a real impact, we want you on our team.\n\nWhat You'll Do:\n\nThe empowered and agile Data Science & Statistics team is charged with creating analytics systems that enable highly effective product development via virtual experimentation, optimization and knowledge discovery. In addition, the team provides data science consulting services to the Lubrizol technical community throughout the world. You'll collaborate with a diverse group of passionate individuals to deliver sustainable solutions to advance mobility, improve wellbeing and enhance modern life.\n\nWhat We're Looking For:\n\nPotential projects (depending on intern skills and current Lubrizol needs):\n• Create predictive models by mining complex data for critical formulating or testing insights\n• Implement and assess algorithms in R, Python, SAS, JMP, or C#/C++\n• Research, develop, and operationalize new statistical, machine learning and/or optimization methods (PhD level)\n• Collaborate with data science team, as well as scientists and engineers, to understand their needs, and find creative solutions to meet those needs\n\nPrevious intern projects include:\n• Predictive modeling using Bayesian and machine learning methods\n• R/Shiny tool development to enable model predictions and formulation optimization\n• Creation of an interactive visualization tool for monitoring predictive models\n• Development of a bootstrap procedure for a hypothesis test\n• Multitask learning (transfer learning) using co-regionalized Gaussian Processes (PhD level)\n• Multivariate variable selection approach using Variational Bayes (PhD level)\n• Multi-objective optimization using genetic algorithms (PhD level)\n• Survival modeling using bagged Cox proportional hazards regression trees (PhD level)\n• Bootstrap variance estimation for complex nonlinear models (PhD level)\n\nSkills That Make a Difference:\n• Enrolled in a Master’s or PhD program such as statistics, data science, machine learning\n• Excellent programming skills with the ability to learn new methods quickly\n• Exposure to database systems and the ability to efficiently manipulate complex data\n• Interest and experience in adva ...
# {'title': 'Senior Data Scientist', 'company_name': 'BoehringerPRD', 'location': 'Fremont, CA', 'via': 'Boehringer Ingelheim Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=tjmUuqOyKViJNgBsAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=tjmUuqOyKViJNgBsAAAAAA%3D%3D', 'extensions': ['26 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '26 days ago', 'schedule_type': 'Full-time'}, 'description': "Description\n\nRole located onsite in Fremont, CA.\n\nAs an employee of Boehringer Ingelheim, you will actively contribute to the discovery, development, and delivery of our products to our patients and customers. Our global presence provides opportunity for all employees to collaborate internationally, offering visibility and opportunity to directly contribute to the companies' success. We realize that our strength and competitive advantage lie with our people. We support our employees in several ways to foster a healthy working environment, meaningful work, diversity and inclusion, mobility, networking, and work-life balance. Our competitive compensation and benefit programs reflect Boehringer Ingelheim's high regard for our employees.\n\nThe Senior Data Scientist will execute data science projects at US Biopharma Fremont with the purpose of solving non-routine business problems by applying advanced methods including artificial intelligence, machine learning, causal inference, advanced statistics, natural language processing and other related techniques.\n\nThe Senior Data Scientist is highly experienced in delivering successful data science projects and will work in close collaboration with different business units (e.g., Biopharma sites in Vienna and Biberach) to develop applications which utilize data for smart decision making.\n\nThe role will include the responsibility for designing and building computational models, discovering insights, and identifying opportunities using statistical and algorithmic methods (for instance machine learning) as well as data visualization techniques. The Senior Data Scientist will utilize their experience to manage small and medium-sized projects, potentially including external support and to develop and mentor more junior colleagues.\n\nDuties & Responsibilities\n\nDelivering successful data science projects:\n• Understands business problems and design end-to-end data science use cases.\n• Collaborates across the business to understand data, and business constraints.\n• Prioritizes, scopes, and measures the corresponding Key Performance Indicators (KPIs)/ Objectives and Key Results (OKRs) for success.\n• Collaborates with developers to implement and deploy scalable solutions.\n• Establishes best data operational practices and maintain all compliance requirements.\n• Establishes the monitoring of data science models in production.\n\nAchieving high analytical quality of delivered projects:\n• Applies strong expertise in data science to design, prototype, and build the next-generation analytics engines and services.\n• Generates hypotheses about the underlying mechanics of the business process together with domain experts.\n• Identifies, evaluates, and implements the most appropriate algorithm for the specific challenge.\n\nEstablishing close collaborations across different departments to transform towards smart data-driven decision making:\n• Guides the organization about the business potential and strategy of artificial intelligence (AI)/data science.\n• Actively networks on a regular basis with domain experts to better understand the business mechanics that generated the data.\n• Quickly develops extensive domain knowledge in various topics.\n• Trains and coaches other business and staff on basic data science principles and techniques.\n\nSuccessful management of communities and partnerships:\n• Actively networks on a regular basis with internal and external partners.\n• Promotes ...

# %% [markdown]
# In web crawling, pagination involves retrieving data across multiple pages of a website. It helps manage large datasets by fetching a limited number of results per request, enabling efficient data extraction without overwhelming the server or exceeding resource limits.
#
# You could use pagination to get more results for a given search, however you need to start where the last search left off.
#
# You can do this by adding the `next_page_token` to the `params` dictionary.
#
# You get the last `next_page_token` from the `result_dict["serpapi_pagination"]`
#
# If you don't do pagination, and search 10 times, you will just get the first 10 results over and over again.

# %%
print(result_dict["serpapi_pagination"],"\n")
print(result_dict["serpapi_pagination"]["next_page_token"])
# Out:
# {'next_page_token': '...', 'next': 'https://serpapi.com/search.json?engine=google_jobs&gl=us&google_domain=google.com&hl=en&next_page_token=...%3D&q=data+science&uule=w%2BCAIQICINVW5pdGVkIFN0YXRlcw'}
#
# ...

# %% [markdown]
# Lets do one more search, but this time with pagination, starting where the last search left off.

# %%
search_query = 'data science'
params = {
	'api_key':API_KEY,                          # https://serpapi.com/manage-api-key
	'uule': 'w+CAIQICINVW5pdGVkIFN0YXRlcw',		# encoded location (USA)
	'q': search_query,              			# search query
    'hl': 'en',                         		# language of the search
    'gl': 'us',                         		# country of the search
    "num": 10,									# number of results per page
	'engine': 'google_jobs',					# SerpApi search engine
    'next_page_token': result_dict["serpapi_pagination"]["next_page_token"]
}

# %%
search = GoogleSearch(params)   			# where data extraction happens on the SerpApi backend
result_dict = search.get_dict() 			# JSON -> Python dict

if 'error' in result_dict:
    print("ERROR FOUND IN SEARCH")

# %%
for result in result_dict['jobs_results']:
    print(result)
    # google_jobs_results.append(result)
# Out:
# {'title': 'Product Manager, Data Science & Analytics (Remote)', 'company_name': 'The Home Depot', 'location': 'Anywhere', 'via': 'The Home Depot Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=94jynhwGXj80buIGAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXLsQrCMBAAUFz7CYJwk6jUVgQXnQqFqiCIuss1HkklvQvJCfWL_E11edvLPqPscI7yeBmFEzJaijnUqAhX0xEbgilUjP6tnUkwu1AvSnNYwlFaSITROBCGRsR6Gu-cakjbskzJFzYp_lZhpC-FqZWhfEqb_tyTw0jBo9J9vVkNRWC7mNwcwV56gpqCKHQMlXpkxRya6gtct7sRqgAAAA&shmds=v1_AXX-3kHmDDMrjc_GzaFuGjtkeiTmB_0hW03ImTUlmWVU9ZFDNg&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=94jynhwGXj80buIGAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab208bf30de0f369b322fe2ec214b178dec8a29c2f5e080d6fb.gif', 'extensions': ['Work from home', 'Full-time', 'No degree mentioned'], 'detected_extensions': {'work_from_home': True, 'schedule_type': 'Full-time', 'qualifications': 'No degree mentioned'}, 'description': "Position Purpose:\n\nThe Product Manager (PM) position is responsible for delivering business value to drive sales, improve efficiency, and improve customer satisfaction through the production of quality products. Within their designated enterprise product line, PMs focus on delivering incremental value by driving product changes and working closely with a team of developers, designers, and business partners. They support in-depth business reviews, communicate and present across all levels of the organization, and support cross-functional product teams.\n\nKey Responsibilities:\n• 40% Strategy & Planning:\n• Gains a thorough understanding of customer and associate needs, both existing and potential, and uses that knowledge to help deliver enterprise products that provide Home Depot customers and associates with an unparalleled shopping experience\n• Translates business goals and end user needs into product strategy; communicates direction and product priorities to the development team, other matrixed teams, and third-party partners\n• Identifies goals, metrics, and analytics to determine product value; continually making recommendations and refinements to the product backlog based on learnings\n• Conduct end user research to help identify user stories and help determine Minimum Viable Product (MVP)\n• Partners with Finance to understand financial needs and assists in the creation of business plans for new opportunities\n• Monitors research as well as the competitive landscape to recommend the best solutions and ensure that products remain or become best in class\n• Evaluates research and market analysis on industry innovations and technology platforms to recommend the best possible solution\n• 30% Delivery & Execution:\n• Ensure product is aligned with company, stakeholder and end-user priorities to drive sales, improve efficiency, and improve customer satisfaction\n• Documents, reviews and ensures that all quality and change control standards are met\n• Formulates, tests and refines assumptions and hypotheses through user research and testing\n• Creates, prioritizes and accepts user stories; incorporate them into release planning\n• Makes product decisions that drive value on a daily basis\n• Identifies pros, cons, issues, obstacles, dependencies and value associated with features and enhancements\n• Participates in standups, iteration planning sessions, product demos and retrospectives\n• Condenses complex technical concepts into non-technical language for stakeholders\n• 30% People:\n• Fosters collaboration with team members (Engineering, User Experience Designers, etc.) to drive value and collectively identify and resolve impediments\n• Acts as a proponent of modern software development practices\n• Advocates for the end user and stakeholder by empathizing with and understanding user needs and becoming the domain expert\n• Regularly works with the product team to continuously assess progr ...
# {'title': 'Data Scientist, Paramount Advertising', 'company_name': 'Paramount', 'location': 'San Francisco, CA', 'via': 'Paramount Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=8JSZx_TLdMwIZ71YAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_0XNMQrCQBBAUWxzBAuZWmJWBBu1CYqClZADhMk67K4kM2FnlNzFy6qVzS9e84v3rDic0BAan4gtqZVww4yDPNmgvr8ofzFxgBVcpQMlzD6CMFxEQk_zfTQbdeecal8FNbTkKy-DE6ZOJveQTn9pNWKmsUejdrNdT9XIYbn4rxJDgwznjOyTeinhWH8A7hWwiJ4AAAA&shmds=v1_AXX-3kHe5qXxYIo5shpOhRNTrf2C4pfit88IzNFlPJm_kweedg&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=8JSZx_TLdMwIZ71YAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab2f51d0d5b14b86e981d7d2a8abefc2ad8043d45444fe5175c.gif', 'extensions': ['18 days ago', 'Full-time', 'Health insurance', 'Paid time off', 'Dental insurance'], 'detected_extensions': {'posted_at': '18 days ago', 'schedule_type': 'Full-time', 'health_insurance': True, 'paid_time_off': True, 'dental_coverage': True}, 'description': "Paramount is looking for a Data Scientist to join the Paramount Ads Team! You will play a pivotal role in transforming raw customer data into actionable insights that inform strategic marketing decisions! You will work closely with cross-functional teams to understand business requirements, design and handle data models, and develop comprehensive dashboards and presentations. You will validate the output of engineering solutions. The ideal candidate will have a strong background in SQL (specifically BigQuery), data modeling, and data visualization tools, with a focus on lead data, lead scoring, customer data, customer scoring, and deriving marketing automation activities.\n\nKey Responsibilities:\n\nData Analysis and Querying:\n• Use SQL, particularly within BigQuery, to extract, transform, and analyze large datasets related to customer behavior, interactions, and demographics.\n• Conduct ad-hoc data queries to address business needs and provide insights into customer segmentation, engagement, and lifetime value.\n\nLead and Customer Scoring:\n• Develop lead scoring models based on historical data and predictive analytics to identify high-value leads and prioritize sales and marketing efforts.\n• Implement customer scoring methodologies to assess customer happiness, dedication, and propensity to purchase.\n\nData Modeling:\n• Craft and maintain data models that successfully gain customer journey touchpoints, lead interactions, and marketing campaign performance metrics.\n• Optimize data for performance and scalability to support real-time analytics and reporting.\n\nSales & Marketing Automation Activities:\n• Collaborate with sales & marketing teams to derive insights from customer data and inform marketing automation activities such as personalized messaging, dynamic content delivery, and lead championing campaigns.\n• Monitor and analyze the efficiency of marketing automation efforts, iterating on strategies to improve engagement and conversion rates.\n\nDashboard Development:\n• Develop interactive dashboards using visualization tools such as Google Looker, Salesforce CRM Analytics, and Excel to track key marketing KPIs, visualize customer segmentation, and monitor campaign performance.\n• Translate complex data into visually compelling and actionable insights for partners across the organization.\n\nData Presentation:\n• Build concise and impactful presentations to communicate key findings, insights, and recommendations to senior leadership and cross-functional teams.\n• Collaborate with teams to ensure data presentations meet business objectives and drive informed decision-making.\n\nQualifications:\n• 3+ years of experience as a Data Scientist\n• Bachelor's degree in Computer Science, Statistics, Mathematics, Economics, or a related field.\n• Strong proficiency in Python and SQL (BigQuery preferred).\n• Expertise in data modeling techniques, predic ...
# {'title': 'Manager Data Scientist', 'company_name': 'Capital One', 'location': 'McLean, VA', 'via': 'Capital One Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=hVulyKx3gNExOU2qAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXEsQoCMQwAUFzvD3TKLF4rgotOoiCIh4PgeqQl9Co1KU2G-wN_W3zD676Lrh-QMVGDCxrCM2Ziy2rQw00CKGGLEwjDVSQVWh0ns6oH71WLS2poObooHy9MQWb_lqD_Rp2wUS1oNO7229lVTuvlGWs2LPBggswwxDshb-B1-gGVqEEPigAAAA&shmds=v1_AXX-3kGa91jo6OYGBKlcWWJ6rpibG8wrgKwXKoyBC-iCMEZQPw&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=hVulyKx3gNExOU2qAAAAAA%3D%3D', 'extensions': ['Full-time and Part-time', 'Health insurance'], 'detected_extensions': {'schedule_type': 'Full-time and Part-time', 'health_insurance': True}, 'description': "Locations: VA - McLean, United States of America, McLean, Virginia\n\nManager Data Scientist\n\nData is at the center of everything we do. As a startup, we disrupted the credit card industry by individually personalizing every credit card offer using statistical modeling and the relational database, cutting edge technology in 1988! Fast-forward a few years, and this little innovation and our passion for data has skyrocketed us to a Fortune 200 company and a leader in the world of data-driven decision-making.\n\nAs a Data Scientist at Capital One, you’ll be part of a team that’s leading the next wave of disruption at a whole new scale, using the latest in computing and machine learning technologies and operating across billions of customer records to unlock the big opportunities that help everyday people save money, time and agony in their financial lives.\n\nRole Description\n\nIn this role, you will:\n• Partner with a cross-functional team of data scientists, software engineers, and product managers to deliver a product customers love\n• Leverage a broad stack of technologies — Python, Conda, AWS, H2O, Spark, and more — to reveal the insights hidden within huge volumes of numeric and textual data\n• Build machine learning models through all phases of development, from design through training, evaluation, validation, and implementation\n• Flex your interpersonal skills to translate the complexity of your work into tangible business goals\n\nThe Ideal Candidate is:\n• Customer first. You love the process of analyzing and creating, but also share our passion to do the right thing. You know at the end of the day it’s about making the right decision for our customers.\n• Innovative. You continually research and evaluate emerging technologies. You stay current on published state-of-the-art methods, technologies, and applications and seek out opportunities to apply them.\n• Creative. You thrive on bringing definition to big, undefined problems. You love asking questions and pushing hard to find answers. You’re not afraid to share a new idea.\n• A leader. You challenge conventional thinking and work with stakeholders to identify and improve the status quo. You’re passionate about talent development for your own team and beyond.\n• Technical. You’re comfortable with open-source languages and are passionate about developing further. You have hands-on experience developing data science solutions using open-source tools and cloud computing platforms.\n• Statistically-minded. You’ve built models, validated them, and backtested them. You know how to interpret a confusion matrix or a ROC curve. You have experience with clustering, classification, sentiment analysis, time series, and deep learning.\n• A data guru. “Big data” doesn’t faze you. You have the skills to retrieve, combine, and analyze data from a variety of sources and structures. You know understanding the data is often the key to great data science.\n\nBasic Qualifications:\n• Currently has, or is in the process of obtaining a Bachelor’s Degree plus 6 years of experience in data analytics, or currently has, or is in the process of obtaining a Master’s Degree plus 4 years of experie ...
# {'title': 'Data Science Solution Specialist - Generative AI', 'company_name': 'Deloitte', 'location': 'Lake Mary, FL', 'via': 'Deloitte Jobs', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=JrOvl2oxCGzN6SCbAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXKQQrCQAxAUdx6A11lLdoRwY2uhGJR6qoHKOkQ2ug4GSZR6nG8qXXz4cObf2fzqkRDaDxT9ASNhJexRGgSecbAarCBiiJlNH4TnC7TX6UDJcx-gIlWIn2g5XEwS3pwTjUUvdrkfeHl6SRSJ6O7S6f_tDpgphTQqN3tt2ORYr9alBSEzQg4Qo0PghvmzxrO9Q__LXlcpAAAAA&shmds=v1_AXX-3kES3mFcrN48DUa2JnjARv1s29_31IJWgvOynBtPVUZzaA&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=JrOvl2oxCGzN6SCbAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab2fceb743be9b7ad5b24e7fd380d9f4388d87888eb4786a177.gif', 'extensions': ['17 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '17 days ago', 'schedule_type': 'Full-time'}, 'description': "Data Scientist (Generative AI) -Solution Specialist - USDC\n\nAre you an experienced, passionate pioneer in technology - a solutions builder, a roll-up-your-sleeves technologist who wants a daily collaborative environment, think-tank feel and share new ideas with your colleagues - without the extensive demands of travel? If so, consider an opportunity with our US Delivery Center - we are breaking the mold of a typical Delivery Center.\n\nOur US Delivery Centers have been growing since 2014 with significant, continued growth on the horizon. Interested? Read more about our opportunity below ...\n\nWork you'll do\n\nThe Generative AI Engineer will, as part of several client delivery teams, be responsible for developing, designing, and maintaining cutting-edge AI-based systems, ensuring smooth and engaging user experiences. Additionally, the Generative AI Engineer will participate in a wide variety of Natural Language Processing activities, including refining and optimizing prompts to improve the outcome of Large Language Models (LLMs), and code and design review. The kinds of activities performed by the Prompt Engineer will also include, but not be limited to:\n• Working across client teams to develop and architect Generative AI solutions using ML and GenAI\n• Developing and promoting standards across the community\n• Evaluating and selecting appropriate AI tools and machine learning models for tasks, as well as building and training working versions of those models using Python and other open-source technologies\n• Working with leadership and stakeholders to identify AI opportunities and promote strategy.\n• Developing and conducting trainings for users across the Government & Public Services landscape on principles used to develop models and how to interact with models to facilitate their business processes.\n• Building and prioritizing backlog for future machine-learning enabled features to support client business processes.\n• You'll design and build generative models, selecting the most suitable architecture (e.g., GANs, VAEs) based on the desired output (text, images, code). This involves writing code using Python libraries like TensorFlow or PyTorch.\n• Once your model is built, you'll train it on the prepared data, fine-tuning hyperparameters to achieve optimal performance. You'll then evaluate the model's outputs to assess its effectiveness and identify areas for improvement.\n• You'll collaborate with other engineers to integrate your generative AI solution into existing systems or develop new applications. This might involve deploying the model on cloud platforms for scalability.\n• The field of generative AI is rapidly evolving. Staying abreast of the latest research, advancements, and ethical considerations in AI development is an ongoing process.\n\nThe TeamArtificial Intelligence & Data Engineering\n\nIn this age of disruption, organizations need to navigate the future with confidence, embracing decision making with clear, data-driven choices that deliver enterp ...
# {'title': 'Senior Data Scientist, ASE iCloud Data Organization [Executive Communications]', 'company_name': 'Apple', 'location': 'Cupertino, CA', 'via': 'Careers At Apple', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=OQDhqdx0kDCsHXCHAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_yXKPQrCQBBAYWw9gIXV1KKJCDZahSiCjUVKEdmsQzKymVl2JhI8m4fzr3nN98av0RgrZJIEO2cOKk_IRmpzKKo9UBmkv_3plBrH9HRGwnDeD-h7owdCKV3XM_kf6AUWcJQaFF3yLXzWg0gTcLptzaJu8lw1ZI3aZ_eZly4XxlqG_C61fnPV1iWMwRleV-vlkEVuZpMixoBADGUfMRmxzKEs3hg2ogG_AAAA&shmds=v1_AXX-3kGxAbvg8ANMnZHMUITSZtZq8FVxx2zxptSU9hQkJ_he5w&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=OQDhqdx0kDCsHXCHAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab20c8702522df13c2550a3c7a964a31b99d7657e2ea9b3cab8.gif', 'extensions': ['Full-time', 'Dental insurance', 'Health insurance'], 'detected_extensions': {'schedule_type': 'Full-time', 'dental_coverage': True, 'health_insurance': True}, 'description': 'Summary\nPosted: Aug 28, 2024\nWeekly Hours: 40\nRole Number:200535761\n\nWould you like to drive the future of Apple’s products, applications, and platform while having the unique opportunity to impact some of the most far-reaching software in the world?\n\nThe Apple Services Engineering (ASE) organization leads the development and innovation on Apple’s cloud-centric products and experiences for users all over the world, including iCloud+, Photos, Mail, Messages, FaceTime, Calendar, Notes, etc. We are the foundation on which Apple’s software developers build the products that our customers love. Our multi-disciplinary data team plays a fundamental role in this mission by partnering closely with product, engineering, and business teams to develop a culture of leveraging data to inform and craft our strategy.\n\nDescription\n\nDescription\nWe are looking for someone with a track record in distilling and communicating technical concepts to senior leadership, leading to better, more data-informed decision making. This role partners closely with business and product teams across ASE. Work includes:\n\n- Connect with and advocate to a wide audience of engineers, managers and executives to influence decisions.\n\n- Craft the narrative for iCloud performance — identify and elevate key insights, and develop scalable approaches for summarizing complex results into an accessible format.\n\n- Collaborate with partners and Data Engineering to define metrics that we will measure our efforts against as well as defining the instrumentation required for yielding sufficient data.\n\n- Extract information from structured and unstructured data.\n\n- Perform exploratory data analyses and use statistics or machine learning techniques to identify key areas of opportunity and new questions to pursue.\n\n- Plan, design, and analyze A/B tests or experiment results.\n\n- Build models to forecast growth, capacity requirements, etc.\n\nMinimum Qualifications\n\nMinimum Qualifications\n\nKey Qualifications\n\nKey Qualifications\n• 5+ years in an analytics or data science role.\n• You have excellent verbal and written communications skills and experience communicating technical concepts to senior executive audiences in order to influence decisions with data.\n• You think about data in terms of statistical distributions and have a big enough analytics toolbox (e.g. Statistics, Machine Learning) to know how to find patterns in data, identify targets for performance, and identify sources of variance about those targets.\n• You use good judgment balancing art and science when visually communicating information (e.g. Tableau, Superset, ggplot).\n• You have engineered information out of massive and complex datasets (e.g. Hive, Spark, Druid).\n• You have proven experience in SQL and at least one programming language (e.g., Python, R, Scala) and are comfortable developing code in a team environment (e.g., git, no ...
# {'title': '(USA) Senior, Data Scientist (Computer Vision Engineer)', 'company_name': 'Walmart Inc.', 'location': 'United States', 'via': 'Workday', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=Qv8aEi6e12Y05NgkAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXMsQrCQAyAYVz7CIKQsYq2IrjoJCqig0upjuV6hjbSJsclQh_Kh7Qu__LBn3wnyT0ti8McCmSSuISTMweFJ2QjNUiP0oePYYQHKQnDmRtixDiHFdykBkUXfQujXESaDqf71izoLs9Vu6xRc0Y-89LnwljLkL-l1n8qbV3E0DnDarNdD1ngZjF7uq530eDKPgNiKJkMX1CMG9QfpNXQI68AAAA&shmds=v1_AXX-3kHLgrcBXEUPlj_KnDla8x0JOlXhhrVBOeZhfVnXVb630w&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=Qv8aEi6e12Y05NgkAAAAAA%3D%3D', 'extensions': ['5 days ago', 'Full-time', 'Health insurance', 'Paid time off', 'Dental insurance'], 'detected_extensions': {'posted_at': '5 days ago', 'schedule_type': 'Full-time', 'health_insurance': True, 'paid_time_off': True, 'dental_coverage': True}, 'description': "Position Summary... What you'll do... As a Computer Vision Engineer, you will be designing, training and deploying state-of-art AI models in real-world production environment. In conjunction with multiple product and technology groups, you will work to create a best-in-class consumer experience in the physical retail space. You’ll sweep us off our feet if…. Experience solving complex problems and comparing alternative solutions, tradeoffs, and diverse points of view to determine a path forward. Demonstrated software engineer experience via an internship, work experience, coding competitions, or widely used contributions in open-source repositories (e.g. GitHub). Experience with research and development of computer vision (object detection, tracking, scene understanding) You’ll make an impact by… Developing computer vision algorithms and machine learning models to enhance different customer facing application. Collaborate within projects within a mixed team of software engineer and computer vision engineer. Follow and apply engineering and computer vision best practices, What you’ll do… Research, develop and analyze computer vision algorithms in areas related to object detection, tracking, product identification and verification, scene understanding. Ensure model robustness, model generalization, accuracy, testability, and efficiency. Write product or system development code. What you’ll bring… Currently has, or is in the process of obtaining, a PhD degree in Computer Science, Computer Vision, relevant technical field, or equivalent practical experience. Or MS with 2 years industry experience Experience in one or more of the following areas: machine learning, deep learning, computer vision Experience in programming languages with a technical background You are a team player - that is, you're a nice person - see no ego. Highly motivated and independent; results oriented. A self-learner: ability to effectively adapt to rapidly changing technology and apply it to business needs, integrate multiple tools together to solve business problems. Analytical Modeling: Requires knowledge of feature relevance and selection; Exploratory data analysis methods and techniques; Advanced statistical methods and best-practice advanced modelling techniques (e.g., graphical models, Bayesian inference, basic level of NLP, Vision, neural networks, SVM, Random Forest etc.); Multivariate calculus; Statistical models behind standard ML models; Advanced excel techniques and Programming languages like R/Python; Basic classical optimization techniques (e.g., Newton-Rapson methods, Gradient descent); Numerical methods of optimization (e.g. Linear Programming, Integer Programming, Quadratic Programming, etc.) To select the analytical modeling technique most suitable for the structured, complex data and develops custom analytical models. Conduct exploratory data analysis activities (for example, basic statistical analysis, hypothesis testing, statistical inferences) on available data. Define and finalize f ...
# {'title': 'Public Notice for Direct Hire (STEM) - Data Scientist', 'company_name': 'Public Health', 'location': 'Philadelphia, PA', 'via': 'Public Health Careers.org', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=dNN8ND6jY-_l37cJAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_y2OQQrCMBBFcdsjuBp3KtqK4EZXQsUiKoW6L5M4NpGYCckIPZVntIKb_-AtHj_7jLJz_VbOariyWE3w4AiljaQFqgEwbW6HywyWUKIgNNqSF5tkECdWkAijNsAejsydo_HOiIS0LYqUXN4lwSGaa34V7ElxXzxZpd-0yWCk4FCoXW9WfR58N5_8r1SETgxYD7WxDu_kgrG4gHr_BZHYnuWxAAAA&shmds=v1_AXX-3kHLjuJSE89CxpPDbKIsXv75o_oa7U_t7qBUPNzJAsYgsw&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=dNN8ND6jY-_l37cJAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab2d453be81bd8f362220ee33e07924d53134cebbc3031e2f97.gif', 'extensions': ['6 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '6 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': 'Summary\n\nThe CDC utilizes Direct Hire Authority to fill vacancies in a variety of occupations. This vacancy is a REPOSITORY of applications. Applications may be periodically referred to hiring managers both during the open period and after the closing date. Because of the large number of applications anticipated, applicants\' status will not be updated.\n\nApplicant Expiration: Applications will expire 4 months after submission/resubmission. To remain eligible for consideration, reapplying is required.\n\nHelp Duties\n\nThe CDC utilizes Direct/Expedited Hire Authorities to fill vacancies in a variety of occupations. This vacancy is a REPOSITORY of applications. Duties and responsibilities vary and may increase according to the grade level of the position. Applications may be periodically referred to hiring managers both during the open period and after the closing date. Because of the large number of applications anticipated, applicants\' status will not be updated.\n\nThis public notice will be used to fill the positions listed below at multiple grade levels and locations.\n• Data Scientist: Grades GS-11 through GS-15\nDuties may include but are not limited to:\n• Performing assigned portions of professional or technical projects involving some or all duties such as: data science to establish objectives and approach; ability to isolate and define critical features of the problem.\n• Reviewing, coordinating, and monitoring implementation of policies governing the program area.\n• Incorporating and/or integrating health equity principles and practices in the development of IT infrastructures, algorithms, concepts, storage, retention, and surveillance programs.\n\nHelp Requirements\nConditions of Employment\n\nDue to the Centers for Disease Control and Prevention\'s (CDC\'s) process enhancement to use Shared Certificates throughout the Agency, some of the requirements below may differ:\n• US Citizenship is required.\n• Males born after December 31, 1959 must be registered or exempt from Selective Service (http://www.sss.gov).\n• May be subject to a Background/Security Investigation. Security clearance level may differ from the position announced when certificates are shared.\n• CDC participates in the USCIS Electronic Employment Eligibility Verification Program (E-Verify). If selected, CDC will determine your employment eligibility using your social security number.\n• Direct deposit is required.\n• One-year probationary period may be required.\n• This position may be subject to a Collective Bargaining Agreement.\n• This public notice may be used to fill supervisory or managerial positions and selectees may be subject to 1 year supervisory or managerial probationary period.\n• Positions may be filled as permanent or term appointments.\n• This position may be subject to the OGE Financial Disclosure requirements of the Ethics in Government Act of 1978 (P.L. 95-521). CDC inspires public confiden ...
# {'title': 'Data Scientist , Global FP&A Technology', 'company_name': 'Amazon.com Services LLC', 'location': 'Seattle, WA', 'via': 'Indeed', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=u1_ts4pkJL6juxagAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXKwQqCQBCAYbr6CJ3m5CFMI-hSEEiREB4Cg44yuwzrxrojzhDW-_Se5eWHD_7ku0iOZ1SExnqK6kUhgyqwwQCXW1rCnWwXObB7wxqubEAIR9sBR6iYXaDloVMdZF8UIiF3oqje5pb7giMZnoonG5nTSocjDQGV2u1uM-VDdKu07PHDcf6hofHlLQnU9Ql8_BtVA2XwKH8FzNkgqAAAAA&shmds=v1_AXX-3kEPizcd8OKhJfGuDLfduViOrnXyAw8FPyocnRrzeSOvkg&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=u1_ts4pkJL6juxagAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab28cc025f05c82b346da3e3c62b1f088d7cd7d8a4e119138df.gif', 'extensions': ['4 days ago', '126K–213K a year', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '4 days ago', 'salary': '126K–213K a year', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "• 3+ years of data querying languages (e.g. SQL), scripting languages (e.g. Python) or statistical/mathematical software (e.g. R, SAS, Matlab, etc.) experience\n• 2+ years of data scientist experience\n• 3+ years of machine learning/statistical modeling data analysis tools and techniques, and parameters that affect their performance experience\n• Bachelor's degree\n• Experience applying theoretical models in an applied environment\n• Master's degree\n\nJoin Amazon's Global FP&A Technology (GFT) team as a Data Scientist, where you'll play a pivotal role in building the Future of FP&A operations through data-driven insights and advanced analytics.\n\nAs part of GFT's mission to streamline, optimize, and drive financial excellence through technology, you'll work closely with Corporate FP&A teams and cross-functional stakeholders to develop scalable data science solutions that support strategic finance objectives. Your work will contribute directly to enhancing reporting, planning, cost allocations, and business enablement tools that empower finance teams across the organization.\n\nWe are looking for a results-driven scientist to join our team in Seattle. You will be interacting FP&A teams, product managers, software engineers, data engineers, UX designers, and front end engineers to understand the key requirements, and lead the design and development of data science products and services. This is a great opportunity for anyone who is looking to drive the next generation of data science architecture, design, and development that scale and support the overall Amazon business growth and FP&A function.\n\nThe key strategic objectives for this role include:\n• Work with the Corporate FP&A organization to provide data- and model-driven guidance and recommendations on business questions posed by leadership.\n• Interact with stakeholders, both technical and non-technical, to gather business requirements and translate them into concrete requirements for data science projects.\n• Identify opportunities to measure and improve productivity with the end goal of driving growth.\n• Own data science projects end-to-end, demonstrating skill in defining key research questions, working with multiple data sources, evaluating competing models, and interpreting and communicating results.\n\nIf you have an entrepreneurial spirit, you know how to deliver results fast, and you have a deeply quantitative, highly innovative approach to solving problems, we want to talk to you!\n\nAbout the team\nGFT team is a Finance Technology team within Corp FP&A. On our team, we enjoy a unique vantage point into everything happening within Amazon. As part of that, this role would be part of a team that is responsible for Company’s enterprise-wide financial planning & analytics environment. The data flowing through our platform directly contributes to decision-making by our CFO and all levels of finance leadership. If  ...
# {'title': 'Data Scientist Intern United States', 'company_name': 'Cisco', 'location': 'Campbell, CA', 'via': 'SitePoint', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=lP3uzQBDla8vW8OtAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXMsQrCMBCAYVy7uzjdLNqI4FIniSC6FueSxCNJSe9C74Y-ho9sXf7p42--m6a7O3XQh4ykWRSepDgTvCkrfqBXpyhwhBd7EHRzSMAED-ZYcHdNqlU6Y0RKG2W1ObSBJ8OEnhczspd_BkluxlrW13C-nJa2UtxvbZbAkAmsm6rHUg5gbz-l28XOkwAAAA&shmds=v1_AXX-3kE5WWyMAB0Jcth8G6Y2MgeJdUgu5yOXMgDSSCx-22Do_w&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=lP3uzQBDla8vW8OtAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab2d4b83088556a42a9e073f7990b2717720f23b4c8b05b8623.gif', 'extensions': ['3 days ago', 'Full-time', 'Paid time off', 'Dental insurance', 'Health insurance'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full-time', 'paid_time_off': True, 'dental_coverage': True, 'health_insurance': True}, 'description': 'Applications are accepted until further notice. Please note this posting is to advertise potential job opportunities. This exact role may not be open today but could open in the near future. When you apply, a Cisco representative may contact you directly if a relevant position opens. Who You\'ll Work With Work on massive structured, unstructured, transactional and real-time data sets from a variety of sources to analyze customer usage patterns and provide actionable, intuitive, impactful insights using metrics, algorithms, and statistics. What You\'ll Do Acquire , clean and structure data from various sources and maintain databases/data systems. Identify , analyze, and interpret trends or patterns in complex data sets Develop, prototype and test predictive algorithms Filter and "clean" data, and review computer reports, printouts, and performance indicators to locate and correct code problems Develop and implement data collection systems and other strategies that optimize statistical efficiency and data quality Interpret data, analyze results using statistical techniques and provide ongoing reports Who You Are You are a methodical problem-solver, adept at navigating the full spectrum of data science challenges from inception to resolution. Your toolkit is stocked with advanced data manipulation skills and the ability to build and iterate on complex data models with ease. Your technical acumen extends to database design and development, as well as data mining and segmentation techniques, allowing you to construct robust data architectures. With your strong analytical abilities, you excel at sifting through vast datasets, organizing and analyzing them with a meticulous eye for detail and a commitment to accuracy. You are the bridge between raw data and meaningful insights, transforming numbers into narratives that drive strategic decisions. Minimum Qualifications Including but not limited to an upcoming graduate of a technical degree or certification program from a Technical Boot Camp, Apprenticeship, Community College or 4-Year University. ecently completed or actively enrolled in a Bachelor\'s or Master\'s degree program in Engineering, Computer Science, Data Science, Statistics or a related field or other academic certification Experience with data science tools and techniques, including data manipulation (SQL, Hadoop, etc.) Experience with programming (R, Python, XML, JavaScript, or ETL) frameworks Knowledge of and experience with reporting packages (Business Objects etc.). Use of statistical packages for analyzing large datasets (Excel, SPSS, SAS etc.). Technical knowledge regarding data models, database design development, data mining and segmentation techniques Proficient in queries, report writing and presenting findings Able to legally live and work in the country for which you\'re applying, without visa support or sponsorship Preferred Qualifications Experience with Oracle da ...
# {'title': 'Senior Director of Data Science', 'company_name': 'Formation Bio', 'location': 'New York, NY', 'via': 'Greenhouse', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=data+science&htidocid=o6ohcN1DwIPJYLlGAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xWMsQrCQBAFsc0nCMLWojkRtDCdBAWLNKlShcux5k6Te-F2wXyIH2xshmlmsu8qO9ccAxKVIbHTRfCk0qql2gWOjmlPD3QkbJPzhEh3oB94XXjVSS7GiAx5L2o1uNxhNIjcYTYvdPJHK94mngar3B5PhzmfYr_d3JDGpVh21wAKkSr-UIP03lHV_ADnAJqblwAAAA&shmds=v1_AXX-3kHja07eb8gkr_ZJ_T2sJX-Tnt1ezlYQk8yJklbnf760zw&shem=jbt1,jbto1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=data+science&htidocid=o6ohcN1DwIPJYLlGAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728597ad11a893f71a2704e/images/2d7133faaf25aab2ae24bddf1fe27da4868eace616fdb4e91515fdd7c3810a26.gif', 'extensions': ['Full-time', 'Health insurance'], 'detected_extensions': {'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "About Formation Bio\n\nFormation Bio is a tech and AI driven pharma company differentiated by radically more efficient drug development.\n\nAdvancements in AI and drug discovery are creating more candidate drugs than the industry can progress because of the high cost and time of clinical trials. Recognizing that this development bottleneck may ultimately limit the number of new medicines that can reach patients, Formation Bio, founded in 2016 as TrialSpark Inc., has built technology platforms, processes, and capabilities to accelerate all aspects of drug development and clinical trials. Formation Bio partners, acquires, or in-licenses drugs from pharma companies, research organizations, and biotechs to develop programs past clinical proof of concept and beyond, ultimately helping to bring new medicines to patients. The company is backed by investors across pharma and tech, including a16z, Sequoia, Sanofi, Thrive Capital, Sam Altman, John Doerr, Spark Capital, SV Angel Growth, and others.\n\nYou can read more at the following links:\n• Our Vision for AI in Pharma\n• Our Current Drug Portfolio\n• Our Technology & Platform\n\nAt Formation Bio, our values are the driving force behind our mission to revolutionize the pharma industry. Every team and individual at the company shares these same values, and every team and individual plays a key part in our mission to bring new treatments to patients faster and more efficiently.\n\nAbout the Position\n\nFormation Bio is seeking a highly skilled and experienced Senior Data Science Directorto join our dynamic team. This critical role will report to the head of Biometrics and will be responsible for leading and developing our data science team and strategy, driving impactful data-driven initiatives, and leveraging data to advance our drug development processes. We aim to build integrated predictive modeling capabilities, including for toxicology and efficacy, to significantly improve drug development efficiency and increase the probability of success.\n\nResponsibilities\n• Leadership and Team Development:\n• Build and lead a high-performing data science team.\n• Mentor and develop team members, fostering a culture of innovation and collaboration.\n• Define and implement the data science strategy in alignment with company objectives.\n• Strategic Data Utilization:\n• Develop and execute strategies to maximize the value of data.\n• Promote and integrate predictive analytics and advanced data science techniques into the drug development processes.\n• Technical Guidance and Innovation:\n• Provide deep technical expertise and mentorship to the data science team.\n• Ensure the adoption of cutting-edge analytical methods and technologies.\n• Drive the development and deployment of machine learning models and AI solutions in collaborations with internal tech teams.\n• Cross-Functional Collaboration:\n• Work closely with development and tech teams to facilitate data-driven decision-making.\n• Collaborate with internal and external stakeholders to stay updated on em ...

# %% [markdown]
# # Utility function
#
# Create utility function to search google jobs, and save the results to a file.
#
# Here is one sketch of what the function might look like:
#
# - Imports the current date and time using `datetime`.
# - Defines `search_google_jobs` to perform a Google Jobs search with a default or custom query.
# - Accepts parameters for the search query, pagination token, and verbosity.
# - Sets search parameters like API key, location, language, and search engine.
# - Appends the pagination token if provided.
# - Creates a timestamped output filename based on the query and time.
# - Does a search and data extraction.
# - Optionally prints the data if `verbose` is `True` and saves results to a JSON file.
# - Returns the `next_page_token` for pagination or handles errors.

# %%
# INSERT CODE HERE
import datetime
def search_google_jobs(search_query, next_page_token=None, verbose=False):
    current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"jobs_results_{search_query.replace(' ', '_')}_{current_time}.json"

    params = {
        'api_key': API_KEY,                         # Replace with your API key
        'uule': 'w+CAIQICINVW5pdGVkIFN0YXRlcw',     # Encoded location (USA)
        'q': search_query,                          # Search query
        'hl': 'en',                                 # Language of the search
        'gl': 'us',                                 # Country of the search
        'num': 10,                                  # Number of results per page
        'engine': 'google_jobs',                    # SerpApi search engine
    }

    if next_page_token:
        params['next_page_token'] = next_page_token

    search = GoogleSearch(params)
    result_dict = search.get_dict()

    if verbose:
        print(json.dumps(result_dict, indent=4))  

    if 'error' in result_dict:
        print("ERROR FOUND IN SEARCH")
        return None, []

    # Save the JSON response to a file
    with open(filename, 'w') as file:
        json.dump(result_dict, file, indent=4)

    jobs_results = result_dict.get('jobs_results', [])
    next_page_token = result_dict.get("serpapi_pagination", {}).get("next_page_token")

    return next_page_token, jobs_results

# %%
next_page_token = search_google_jobs(search_query="machine learning engineer", verbose=True)
# Out:
# {'title': 'Machine Learning Engineer', 'company_name': 'Apple', 'location': 'Austin, TX', 'via': 'Careers At Apple', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=MMbmdDm79xD9nKF9AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=MMbmdDm79xD9nKF9AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728653ff79a0150f41a2bda/images/1721331cca54d3a6bd2659205cb921ad0ac69ef13e72054cb9b92c9640189527.png', 'extensions': ['18 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '18 days ago', 'schedule_type': 'Full-time'}, 'description': 'Summary\nPosted: Oct 17, 2024\n\nRole Number:200573979\n\nImagine what you could do here! The people here at Apple don’t just create products — they build the kind of wonder that’s revolutionized entire industries. It’s the diversity of those people and their ideas that inspires the innovation that runs through everything we do, from amazing technology to industry-leading environmental efforts. At Apple, inclusion is a shared responsibility, and we work together to foster a culture where everyone belongs and is inspired to do their best work.\n\nHere on the Apple Store Online team, we are responsible for Apple’s largest store. Our main goal is to deliver a magical, personal digital experience where customers can shop, buy and learn everything Apple, wherever they are. Each customer should feel like they are our only customer and our job is to set the bar for the experience they receive. To run such an extraordinary store, it takes extraordinary people, and we are looking for someone to help us do extraordinary things.\n\nWe are looking for a passionate, highly motivated, and hands-on applied Machine Learning Engineer. This role will lead the way on our Online Retail Decision Automation team by researching and developing the next generation of algorithms used to drive the Apple Online experience! The role spans central areas of our Apple Online Store including developing models for product search, recommendation systems (e.g. ranking, page generation), personalization (e.g. evidence, messaging, marketing), Generative AI and optimizing Apple-wide systems & infrastructure. As a member of the fast-paced team, you will have the outstanding and great opportunity to be part of new projects and craft upcoming products that will delight and encourage millions of Appleʼs customers every day.\n\nDescription\n\nDescription\nTo be successful, candidates will need a strong machine learning background, proven software development skills, a love of learning, and to collaborate with cross-functional teams, including researchers, engineers, data scientists/analysts, and product managers, to develop and implement machine learning algorithms. Mentor other MLE’s and lead an effort to build scalable end-to-end machine learning solutions for our retail customers.\n\nRESPONSIBILITIES INCLUDE:\n- Collaborate with other MLEs to build scalable, production-ready ML solutions, taking algorithms from initial concept through to deployment.\n\n- Contribute to the ongoing improvement of our ML infrastructure and tooling.\n\n- Engage in continuous learning and development, staying up-to-date with the latest advances in machine learning and software engineering.\n\nMinimum Qualifications\n\nMinimum Qualifications\n• 5+ years of related experience, including 2+ years experience in machine learning.\n• Proficiency in one or more object-oriented programming languages such as Python, Java, C++ and experience building highly scalable distributed systems.\n• End-to-end hands-on experience with building data processing pipelines, large scale machine learning systems, and big data technologies (eg: Spark, SQL, Snowflake/Hadoop, etc).\n• Understanding of machine learning model lifecycle from prototyping, feature engineering, training, inference, deployment, monitoring and continuous improvements via deep analys ...
# {'title': 'Lead Machine Learning Engineer - Supply Chain', 'company_name': 'Nike', 'location': 'Beaverton, OR', 'via': 'Nike Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=JWh428YGChGLeCD3AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=JWh428YGChGLeCD3AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728653ff79a0150f41a2bda/images/1721331cca54d3a631e6bb8eae3481747b5db514ac839a065c280dcfa9218f1b.png', 'extensions': ['Full-time'], 'detected_extensions': {'schedule_type': 'Full-time'}, 'description': "Become a Part of the NIKE, Inc. Team\n\nNIKE, Inc. does more than outfit the world’s best athletes. It is a place to explore potential, obliterate boundaries and push out the edges of what can be. The company looks for people who can grow, think, dream and create. Its culture thrives by embracing diversity and rewarding imagination. The brand seeks achievers, leaders and visionaries. At NIKE, Inc. it’s about each person bringing skills and passion to a challenging and constantly evolving game.\n\nOpen to remote work except in South Dakota, Vermont and West Virginia.\n\nThe annual base salary for this position ranges from $119,400.00 in our lowest geographic market to $267,500.00 in our highest geographic market. Actual salary will vary based on a candidate's location, qualifications, skills and experience.\n\nInformation about benefits can be found here.\n\nThis posting is for five Lead ML Engineer positions within the Enterprise AI/ML function.\n\nWHO ARE WE LOOKING FOR\n\nWe seek passionate engineers to join our team. As a Lead Machine Learning Engineer, you will develop robust advanced analytics and machine learning solutions that have a direct impact on the business. You should have experience in Python; a strong background in algorithms and data structures; hands-on AWS experience; as well as experience in database technology (e.g. Postgres, Redis) and data processing technology (e.g. EMR). You should also have a demonstrable history of team leadership and value delivery, and be comfortable working in an agile product model. As a Lead ML Engineer, you will be expected to own projects end-to-end - from conception to operationalization, demonstrating an understanding of the full software development lifecycle. As a result, you will be expected to provide technical vision and guidance to your teammates; therefore, strong communication skills are critical in this role.\n\nWHAT WILL YOU WORK ON\n\nIf this is you, you’ll be working with the Artificial Intelligence and Machine Learning (AI/ML) team at Nike. With teammates in Portland, Boston, and Poland, you’ll be joining a global organization working to solve machine learning problems at scale. You’ll be designing and implementing scalable applications that leverage prediction models and optimization programs to deliver data driven decisions that result in immense business impact. You’ll also contribute to core advanced analytics and machine learning platforms and tools to enable both prediction and optimization model development. You thrive when surrounded by talented colleagues and aim to never stop learning. We are looking for candidates who enjoy a collaborative and academic environment where we develop and share new skills, mentor, and contribute knowledge and software back to the analytics and engineering communities both within Nike and at-large.\n\nWe value and nurture our culture by seeking to always be collaborative, intellectually curious, fun, open, and diverse.\n\nWHO WILL YOU WORK WITH\n\nIn this role, you’ll be working closely with the rest of our global team, along with commercial and consumer analytics, and enterprise architecture teams.\n\nWHAT YOU BRING\n• Bachelor's degree in Computer Science, or combination of relevant education, experience.\n• 5+ years of professional experience in software engineering, data engineering,  ...
# {'title': 'Senior Machine Learning Engineer (Python, Spark/Dask, MLOPS)', 'company_name': 'RemoteWorker CA', 'location': 'York, PA', 'via': 'LinkedIn', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=T7hbVhzS36-70SFwAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=T7hbVhzS36-70SFwAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728653ff79a0150f41a2bda/images/1721331cca54d3a64fec0a05fcfbb188f6d93ac0f875abfaf436e47c6ecaa418.jpeg', 'extensions': ['3 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "11 West 19th Street (22008), United States of America, New York, New York\n\nSenior Machine Learning Engineer (Python, Spark/Dask, MLOPS)\n\nAs a Capital One Machine Learning Engineer (MLE), you'll be part of an Agile team dedicated to productionizing machine learning applications and systems at scale. You’ll participate in the detailed technical design, development, and implementation of machine learning applications using existing and emerging technology platforms. You’ll focus on machine learning architectural design, develop and review model and application code, and ensure high availability and performance of our machine learning applications. You'll have the opportunity to continuously learn and apply the latest innovations and best practices in machine learning engineering.\n\nWhat You’ll Do In The Role\n• The MLE role overlaps with many disciplines, such as Ops, Modeling, and Data Engineering. In this role, you'll be expected to perform many ML engineering activities, including one or more of the following:\n• Design, build, and/or deliver ML models and components that solve real-world business problems, while working in collaboration with the Product and Data Science teams.\n• Inform your ML infrastructure decisions using your understanding of ML modeling techniques and issues, including choice of model, data, and feature selection, model training, hyperparameter tuning, dimensionality, bias/variance, and validation).\n• Solve complex problems by writing and testing application code, developing and validating ML models, and automating tests and deployment.\n• Collaborate as part of a cross-functional Agile team to create and enhance software that enables state-of-the-art big data and ML applications.\n• Retrain, maintain, and monitor models in production.\n• Leverage or build cloud-based architectures, technologies, and/or platforms to deliver optimized ML models at scale.\n• Construct optimized data pipelines to feed ML models.\n• Leverage continuous integration and continuous deployment best practices, including test automation and monitoring, to ensure successful deployment of ML models and application code.\n• Ensure all code is well-managed to reduce vulnerabilities, models are well-governed from a risk perspective, and the ML follows best practices in Responsible and Explainable AI.\n• Use programming languages like Python, Scala, or Java.\n\nBasic Qualifications\n• Bachelor’s degree\n• At least 4 years of experience programming with Python, Scala, or Java (Internship experience does not apply)\n• At least 3 years of experience designing and building data-intensive solutions using distributed computing\n• At least 2 years of on-the-job experience with an industry recognized ML frameworks (scikit-learn, PyTorch, Dask, Spark, or TensorFlow)\n• At least 1 year of experience productionizing, monitoring, and maintaining models\n\nPreferred Qualifications\n• 1+ years of experience building, scaling, and optimizing ML systems\n• 1+ years of experience with data gathering and preparation for ML models\n• 2+ years of experience developing performant, resilient, and maintainable code\n• Experience developing and deploying ML solutions in a public cloud such as AWS, Azure, or Google Cl ...
# {'title': 'Machine Learning Engineer III', 'company_name': 'Chewy', 'location': 'Boston, MA', 'via': 'Careers At Chewy, Inc. - Chewy.com', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=-baV5ySu3mdh7dBKAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=-baV5ySu3mdh7dBKAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728653ff79a0150f41a2bda/images/1721331cca54d3a643d2c2a37fa9332a58f1a6108ba69f0a2e4bf94d0b1aa922.png', 'extensions': ['3 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full-time'}, 'description': "Our Opportunity:\n\nChewy is looking for a Machine Learning Engineer III to join our Merchandising Data Science Team. In this role, you will combine an understanding of machine learning, data analysis, statistical testing, and software development. As a Machine Learning Engineer, you will play a meaningful part in crafting, implementing, and deploying machine learning models to address critical problems for our Retail Operations business partners. The ideal candidate will operate as a full stack data scientist who should have expertise in both machine learning and cloud technologies, with a focus on deploying and scaling machine learning models in cloud environments. You will have the chance to create and develop backend ML frameworks best suited for different business problems and build engineering pipelines to streamline model deployment. Does this sound like you? If so, we would love to hear from you!\n\nWhat you'll do:\n• Design, develop, and implement machine learning models for various applications, including but not limited to predictive analytics, natural language processing, and computer vision.\n• Research and implement innovative machine learning algorithms to address specific business challenges.\n• Design and implement cloud architectures tailored for end-to-end machine learning workflows (including data preprocessing, model training, and deployment), ensuring scalability, reliability, and performance.\n• Use Infrastructure as Code (IaC) tools, such as Terraform or AWS CloudFormation, to automate the provisioning and management of cloud resources for machine learning.\n• Implement and handle containerization solutions (e.g., Docker or equivalent) and orchestration tools (e.g., Kubernetes) for deploying and scaling machine learning applications.\n• Collaborate with multi-functional teams, including data scientists, software engineers, and domain experts, to understand requirements and deliver effective solutions.\n• Document code, algorithms and ensure reproducibility.\n• Provide technical mentorship in standard methodologies for model development and deployment to the data science team.\n• Effectively communicate technical concepts and insights to both technical and non-technical customers.\n\nWhat you'll need:\n• Candidate must possess a Graduate Degree (MS or PhD or equivalent experience) in Data Science, Machine Learning, Statistics, Mathematics, or related field.\n• 7+ yease of experience in developing and deploying machine learning models and algorithms in a production environment.\n• Strong understanding of statistical analysis, machine learning, and deep learning techniques.\n• Expertise in programming languages such as Python.\n• Proficiency with SQL\n• Strong understanding of cloud platforms such as AWS.\n• Proficiency in Infrastructure as Code tools (e.g., Terraform, CloudFormation).\n• Experience with containerization and orchestration tools (e.g., Docker, Kubernetes).\n• Proficiency with version control systems (e.g., Git) and coding practices.\n• Strong problem-solving skills and the ability to work independently and in a fast-paced environment.\n• Excellent oral and written communication skills including collaboration with both technical and non-technical customers.\n• Ability to travel up to 10% of the time\n\nChewy is c ...
# {'title': 'Machine Learning/AI Engineer', 'company_name': 'Keysight Technologies, Inc.', 'location': 'Santa Rosa, CA (+1 other)', 'via': 'Keysight Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=bmNs6pGbm5RTTy5JAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=bmNs6pGbm5RTTy5JAAAAAA%3D%3D', 'extensions': ['Full-time', 'Health insurance', 'Paid time off', 'Dental insurance'], 'detected_extensions': {'schedule_type': 'Full-time', 'health_insurance': True, 'paid_time_off': True, 'dental_coverage': True}, 'description': 'Overview\n\nKeysight is on the forefront of technology innovation, delivering breakthroughs and trusted insights in electronic design, simulation, prototyping, test, manufacturing, and optimization. Our ~15,000 employees create world-class solutions in communications, 5G, automotive, energy, quantum, aerospace, defense, and semiconductor markets for customers in over 100 countries. Learn more about what we do.\n\nOur powerful, award-winning culture embraces a bold vision of where technology can take us and a passion for tackling challenging problems with industry-first solutions. Diversity, equity & inclusion are integral parts of our culture and drivers of innovation at Keysight. We believe that when people feel a sense of belonging, they can be more creative, innovative, and thrive at all points in their careers.\n\nThis position is for an AI/ML engineer for Keysight electronic design automation (EDA) software business unit. Keysight EDA solutions empower communication product design, semiconductor manufacturing, and R&D integrators worldwide. We create world-class tools for electronic communication, including software like ADS, EMPro, GoldenGate, SystemVue, IC-CAP, and MBP/MQA.\n\nAs an AI/ML Engineer, you’ll be at the forefront of integrating artificial intelligence and machine learning techniques into our EDA tools. Your primary responsibility will be to develop, implement, and optimize AI/ML models for various EDA applications. Additionally, you’ll take ownership of MLOps practices and ensure the quality and reliability of AI/ML versions\n\nResponsibilities\n• Design and develop machine learning systems tailored for EDA applications.\n• Implement appropriate ML algorithms and techniques.\n• Process and analyze large volumes of data to create predictive models.\n• Collaborate with software developers to integrate AI/ML features into EDA tools.\n• Establish MLOps pipelines for model deployment, monitoring, and maintenance.\n• Conduct rigorous testing and quality assurance of AI/ML versions.\n• Continuously monitor and update models to optimize performance.\n• Stay informed about the latest developments in AI/ML and their applicability to EDA.\n\nQualifications\n\nQualification required -\n• 3- 5 Years of industrial experience\n• PHD/MTech in the area of AI/ML\n• Strong proficiency in programming languages such as Python\n• Basic knowledge of C++ is desired\n• Strong understanding of Nueral Networks, Reinforcement Learning, GenAI\n• Solid understanding of machine learning algorithms, techniques, and libraries (e.g., TensorFlow, PyTorch, scikit-learn).\n• Experience with data preprocessing, feature engineering, and model evaluation.\n• Good understanding of MLOps\n• AI solution deployment experience both on-prem and cloud\n• Proficiency in data manipulation and analysis using SQL, pandas, or similar tools.\n• Familiarity with software development methodologies and version control systems (e.g., Git).\n• Knowledge of cloud platforms (e.g., AWS, Azure, Google Cloud) and containerization technologies (e.g., Docker, Kubernetes) is a plus.\n• Excellent problem-solving skills and analytical thinking.\n• Strong communication and interpersonal skills.\n\nCareers Privacy Statement\n• **Keysight is an Equal Opportunity Employer.***\n\nKeysight Technologies Inc. is an equal opportunity employer ...
# {'title': 'AI/Machine Learning Engineer', 'company_name': 'Bansar Technologies Inc.', 'location': 'Austin, TX', 'via': 'Dice', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=vfqBYeE9KTp19fEgAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=vfqBYeE9KTp19fEgAAAAAA%3D%3D', 'extensions': ['3 days ago', 'Contractor'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Contractor'}, 'description': 'Direct Client: Texas Department of Transportation(TXDOT)\nSolicitation#SCTASK1316247\nTitle: AI / Machine Learning Engineer\nLocation: 6230 E Stassney Ln. Austin TX 78744\nDuration: 12 months with possible extension\nLast date for submission: November 7, 2024 (2.00 PM-CST)\n\nImportant Note: Position requires minimum 2 days onsite in a week.\n\nKey Responsibilities\nModel Development and Design: Develop, test, and optimize machine learning models for classification, regression, clustering, or recommendation tasks.\nData Preparation: work alongside the Enterprise Data Management Team to collect, clean, preprocess, and analyze large datasets to create high-quality training datasets.\nAlgorithm Implementation: Implement machine learning algorithms and neural networks using frameworks like TensorFlow, PyTorch, and scikit-learn.\nDeployment and Integration: Deploy trained models into production environments using APIs, containers (e.g., Docker), or cloud services (AWS, Google Cloud Platform, or Azure).\nPerformance Monitoring: Monitor model performance, detect drift, and implement improvements or retraining strategies to ensure models remain accurate over time.\nCollaboration: Work closely with our data management team, applications team, enterprise architects, and product managers to align solutions with business needs.\nDocumentation: Create thorough documentation for models, processes, and experiments to ensure reproducibility and scalability.\nMLOps Practices: Develop automated pipelines for continuous integration, delivery, and model retraining (CI/CD).\nEthics and Compliance: Ensure AI models comply with industry regulations, address biases, and adhere to ethical standards.\n\nMinimum Skills\nEducation: Bachelor s or Master s degree in Computer Science, Data Science, Mathematics, Engineering, or a related field.\nProgramming Skills: Proficiency in Python, R, or similar programming languages.\nMachine Learning Frameworks: Experience with TensorFlow, PyTorch, Keras, or scikit-learn.\nData Handling: Strong understanding of SQL, NoSQL, and big data tools (e.g., Spark, Hadoop).\nCloud Platforms: Familiarity with AWS, Google Cloud, or Microsoft Azure for deploying ML models.\nModel Evaluation: Expertise in using metrics like accuracy, precision, recall, RMSE, or AUC-ROC for performance evaluation.\nVersion Control: Experience with GitHub, GitLab, or other version control tools.\nProblem Solving: Strong analytical and problem-solving skills.\nCommunication: Ability to explain complex AI/ML concepts to non-technical stakeholders.\n\nPreferred Skills\nKnowledge of MLOps frameworks such as Kubeflow or MLflow.\nExperience with natural language processing (NLP), computer vision, or time-series forecasting.\nFamiliarity with APIs and microservices (e.g., FastAPI, Flask).\nBackground in statistical modeling and probability theory.\nUnderstanding of bias detection and ethical AI principles.\nUnderstanding Microsoft Co-Pilot and usability monitoring for similar AI tools.', 'job_highlights': [{'title': 'Qualifications', 'items': ['Education: Bachelor s or Master s degree in Computer Science, Data Science, Mathematics, Engineering, or a related field', 'Programming Skills: Proficiency in Python, R, or similar programming languages', 'Machine Learning Frameworks: Experience with TensorFlow, PyTorch, Keras, or scikit-learn', 'Data Handling: Strong understanding of SQL, NoSQL, and big data tools (e.g., Spark, Hadoop)', ' ...
# {'title': 'Machine Learning Engineer, OS Intelligence', 'company_name': 'Apple', 'location': 'Seattle, WA', 'via': 'Careers At Apple', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=LL9QzEyoaYk-8vGZAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=LL9QzEyoaYk-8vGZAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728653ff79a0150f41a2bda/images/1721331cca54d3a6502ad6e30ad9e0123320201818112ea578ff7c52c8a0ae3d.png', 'extensions': ['Full-time', 'Health insurance', 'Dental insurance'], 'detected_extensions': {'schedule_type': 'Full-time', 'health_insurance': True, 'dental_coverage': True}, 'description': "Summary\nPosted: Aug 12, 2024\n\nRole Number:200562011\n\nAre you excited about the ways Machine Learning can make all Apple products more intelligent and personalized? From extending your battery life, to accelerating app launches, to preserving your battery health, the OS Intelligence team builds innovative ML solutions ranging from predictive forecasting models to deep foundation models that improve the user experience originating from the core of the operating system. Within the umbrella of Core OS Power & Performance, the Energy Technologies division focuses on solving key resource tradeoff and optimization problems, which sets Apple products apart. The OS Intelligence team within this group is a focused Applied Machine Learning team that imbues the low layers of the operating system with Machine Learning-based intelligence and ships key features and technologies in every year’s OS releases.\n\nThe team is looking for extraordinary candidates to design Deep Learning architectures, implement industry-leading Machine Learning algorithms, as well as contribute high-quality software to iOS, iPadOS, macOS, watchOS, visionOS, and more. In this unique and highly visible role, you will be working cross-functionally to add intelligence to new domains to create beautiful user experiences. Through data analysis, ML model development, and on-device software development, you will push the boundary of what's possible in an operating system.\n\nDescription\n\nDescription\nIn this role, you will have the opportunity to:\n\n-Innovate, conceptualize, and prototype novel intelligent experiences by leveraging recent advances in LLMs, sequence-to-sequence models, and fine-tuning (like LoRA adapters, RAG pipelines) to architect foundation models for a diverse set of applications in the OS.\n\n-Build scalable cloud-based and on-device infrastructure to accelerate seamlessly running experiments and monitoring shipped models.\n\n-Analyze, understand, and present key performance data for highly-visible OS features.\n\n-Write elegant, performant code in Objective-C or Swift and test, debug, and productize it.\n\n-Consult with and influence other teams to drive adoption of new APIs.\n\nMinimum Qualifications\n\nMinimum Qualifications\n• Bachelor’s degree in Computer Science or equivalent work experience.\n• Strong programming background and a clear understanding of operating system components.\n• Familiarity with statistics, data analysis, or machine learning and the enthusiasm to learn more.\n• Highly professional and collaborative with outstanding communication and presentation skills.\n• Proven track record leading software projects from inception through customer delivery.\n• Ability to deliver high quality work on tight schedules consistently.\n\nKey Qualifications\n\nKey Qualifications\n\nPreferred Qualifications\n\nPreferred Qualifications\n• Familiarity with Python, Objective C, or Swift.\n• Familiarity with Deep Learning libraries like PyTorch and Tensorflow.\n• Experience building and leading Applied Machine Learning projects in industry or academia.\n\nEducation & Experience\n\nEducation & Experience\n\nAdditional Requirements\n\nAdditional Requirements\n\nPay & Benefits\n\nPay & Benefits\n• At Apple, base pay is o ...
# {'title': 'Senior Machine Learning Engineer', 'company_name': 'IntelliPro Group', 'location': 'Fremont, CA', 'via': 'Adzuna', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=Knfm0EWG8sm_S6vtAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=Knfm0EWG8sm_S6vtAAAAAA%3D%3D', 'extensions': ['22 hours ago', '130K–180K a year', 'Full-time'], 'detected_extensions': {'posted_at': '22 hours ago', 'salary': '130K–180K a year', 'schedule_type': 'Full-time'}, 'description': "Position Type: Full Time\nLocation: Remote\nSalary Range / Rate (Currency): $130,000 - $180,000 per year\nJob ID#: #148181\n\nCompany Overview\nBacked by top-tier investors, including a16z, and are building the monetization layer for the next generation of Generative AI traffic. Our mission is to create a real-time information layer for the GenAI age, where AI-native content takes center stage and drives consumer engagement. If you're passionate about cutting-edge technologies and building scalable systems, this is the perfect opportunity for you.\n\nRole Overview\nAs a Senior Machine Learning Engineer, you will play a crucial role in designing and building scalable machine learning systems that power our AI-native ad platform. You will collaborate closely with the engineering team to develop and optimize ML models and pipelines, integrating them into a low-latency, high-throughput backend system.\nResponsibilities\n• Develop, train, and deploy machine learning models that drive ad recommendations and bidding systems within our AI-native advertising platform.\n• Build and optimize NLP pipelines to interpret user intent, enabling real-time product recommendations and personalized ads.\n• Design and scale the machine learning infrastructure to support large-scale, AI-driven ad systems, ensuring low latency and high reliability.\n• Explore and implement new ML algorithms and techniques to continuously improve system performance and scalability.\n• Collaborate closely with cross-functional teams, including backend engineers and product managers, to align business objectives with technical solutions.\n• Utilize cloud platforms (GCP, AWS) and distributed computing technologies to manage and scale machine learning models.\nRequirements\n• Proven experience in machine learning, with expertise in deep learning architectures and frameworks like PyTorch or TensorFlow.\n• Strong proficiency in NLP (Natural Language Processing) and large language models (LLMs), including experience building and optimizing embedding models.\n• Hands-on experience with Python and related ML libraries.\n• Knowledge of backend systems, including API development, database optimization, and high-concurrency environment management.\n• Experience in ads systems, including familiarity with bidding, auction algorithms, and optimizing ad performance metrics.\n• Experience with cloud platforms (GCP, AWS) and distributed computing technologies is a plus.\n• Strong problem-solving skills, ability to iterate quickly, and eagerness to experiment with innovative solutions.\n• Self-starter mindset with the ability to work independently in a remote, fast-paced startup environment.\n• Mandarin or experience working with international teams is a plus but not required.\n\nAbout Us:\nFounded in 2009, IntelliPro is a global leader in talent acquisition and HR solutions. Our commitment to delivering unparalleled service to clients, fostering employee growth, and building enduring partnerships sets us apart. With a dynamic presence in the USA, China, Canada, Singapore, Philippines, UK, India, Netherlands, and Germany, we continue leading global talent solutions.\nIntelliPro, a global leader connecting individuals with rewarding employment opportunities, is dedicated to understanding your career aspirations. As an Equal Opportunity Employer, IntelliPro values diversity and does not discriminate based on rac ...
# {'title': 'Scientific Programming and Machine Learning Engineer', 'company_name': 'Leidos', 'location': 'Eglin AFB, FL', 'via': 'Leidos Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=UwXCV0emJXMyWLaCAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=UwXCV0emJXMyWLaCAAAAAA%3D%3D', 'extensions': ['25 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '25 days ago', 'schedule_type': 'Full-time'}, 'description': 'Description\n\nLeidos is looking for scientific programmers, computer scientists, or mathematicians with an Artificial Intelligence/Machine Learning (AI/ML) background to support our growing work in the Eglin office. In this capacity you will propose, design and develop new Artificial Intelligence/Machine Learning (AI/ML) tools to support the design and analysis of high speed weapons systems. Leidos presently uses deep learning Artificial Neural Networks (ANN)s for the purpose of providing fast running models, and thus you would maintain existing ANN’s in addition to developing new ANN based fast running models.\n\nIn this position you will work directly with accomplished aerospace, mechanical, and electrical engineers both internal to Leidos and with external customers. You will need to effectively propose new research ideas to the customer, execute on the research, and present verbal and written status reports. The ability to publish research papers in academic journals and present conference papers is a requirement.\n\nApply your skills to develop advanced AI/ML techniques to model aerodynamic, structural and thermal phenomena. Perform research that develops new techniques to improve the modeling of emerging high speed weapons systems. Develop tools that enable the future of Digital Engineering. Join a team that is helping to secure the nation.\n\nBe part of a close knit team and work with world class experts. The Aerophysics group operates in a small team environment where individual creativity is rewarded and continuous learning is the norm. Our engineers typically work directly with DOD personnel and regularly interact with contracting teams from Lockheed Martin, Boeing, Northrup Grumman, etc. The Destin-Fort Walton Beach-Niceville area is home to world famous beaches and a relaxed ‘salt-life’ lifestyle.\n\nExperience Level: BS and 12+ years of experience required. MS or PhD in Mathematics, Engineering, Computer Science, Machine Learning preferred.\n\nCitizenship: Must be a US Citizen and have an active SECRET clearance.\nCandidate must be located in or willing to relocate to the Eglin AFB, FL area\nMachine Learning: Experience with POD or PCA, scikit, TensorFlow, Keras, PyTorch, or equivalent is required\nProgramming Skills: Python, C/C++, Matlab, Fortran, Linux, Bash scripting\nEngineering Skills: Preferred candidates will be familiar with at least one of the following Modeling and Simulation disciplines: Computational Fluid Dynamics (CFD), heat transfer, dynamics, controls, Finite Element Analysis (FEA), structural/materials engineering.\nCommunication Skills: Successful candidates should be able to effectively communicate with Leidos aerodynamics, airframe, and guidance and control personnel, and interact daily with customers, team members and end users. Must develop a clear understanding of customer goals and objectives and shape work activities to satisfy them. Must present both verbal and written status on a regular basis, and prepare manuscripts for publication at technical conferences and for professional journals.\n\nDesire Skills:\nCandidates with the skills described below will be given preference.\nProgramming: OOP, Numpy, Scipy, LAPACK, BLAS, MPI, Git, CUDA\nCFD: CART3D, Kestrel, FUN3D, US3D, CFD++, Pointwise\nFEM: ANSYS, Sierra Tool suite, LS-Dyna\nCAD: Solidworks\nHPC: PBS or Slurm or other demonstrated skills on utilizing HPCs\n\nLInC\n\nElectronic Warfare\n\n ...
# {'title': 'Senior Software Engineer (Machine Learning & Infrastructure), Acrobat AI Assistant', 'company_name': 'Adobe', 'location': 'San Jose, CA (+1 other)', 'via': 'Adobe Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=qmMZRfIQrw_4lfB3AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=qmMZRfIQrw_4lfB3AAAAAA%3D%3D', 'extensions': ['12 days ago', 'Full-time'], 'detected_extensions': {'posted_at': '12 days ago', 'schedule_type': 'Full-time'}, 'description': "JOB LEVEL\nP40\n\nEMPLOYEE ROLE\nIndividual Contributor\n\nThe Opportunity:\n\nAdobe Document Cloud's AI team is looking for a Senior Software Engineer to improve our upcoming features. Our platform handles billions of PDFs and millions of transactions each month. Join our core team responsible for managing the central repository that supports all feature development and backend services for the Acrobat AI Assistant. This role plays a key role in facilitating fast feature development and building reliable components that are used extensively every day to serve our customers. We support features like question-answering (QA), suggested and related questions, attributions, document summaries, and more.\n\nOur latest public features include Liquid Mode for PDFs on phones and tablets, PDF Extract API for unlocking PDF structure and content, Table Decomposition in Liquid Mode, and new generative AI features. All products use AI and are available on mobile, cloud, and desktop.\nWhat You’ll Do:\n• Design, build, and maintain scalable and efficient code solutions for the Acrobat AI Assistant.\n• Develop and review specifications for safe client-service contracts, ensuring clear, concise, and secure interactions.\n• Apply standard methodologies in code layering and modular design to ensure the development of robust and easily maintainable codebases.\n• Conduct detailed reviews of pull requests and debug complex service integration issues.\n• Lead the coordination and execution of service releases, ensuring they meet rigorous production standards.\n• Work closely with feature teams to facilitate effective communication and knowledge sharing.\n• Accelerate engineering productivity by empowering your fellow engineers with excellent tooling and systems.\n• Build and provide operational support for globally deployed systems, powering some of the most advanced products in the market.\nWhat You’ll Need to Succeed:\n• B.S., M.Sc., or Ph.D. in Computer Science or equivalent practical experience with 5+ years of experience.\n• Extensive software development experience, specifically in backend infrastructure, emphasizing code organization and architectural standard methodologies.\n• Proficiency in designing and implementing concurrent and asynchronous systems using languages such as Python, JavaScript (Node.js), or Go.\n• Familiarity with integrating language models within a feature pipeline.\n• Strong understanding of event-driven architectures and non-blocking I/O operations.\n• Understanding of OOP principles such as encapsulation, inheritance, polymorphism, and abstraction.\n• Familiarity with common design patterns (e.g., Singleton, Factory, Observer, Strategy).\n• Proficiency in writing unit and integration tests for object-oriented systems. Strong debugging skills.\n• Proficiency in Python, with the ability to write clean, unit-tested, and well-documented code using docstrings. Familiarity with frameworks such as LangChain and Pydantic is highly desirable.\n• Familiarity with prompt engineering, vector search techniques, and similar AI/ML technologies.\n• Experience or willingness to learn how to create and review specifications for client-service contracts.\n• Strong interpersonal skills with the ability to lead, mentor, and work collaboratively in a fast-paced environment.\n• A proactive approach to identifying and resolving technical challenges independent ...

# %%
next_page_token
# Out:
# '...'

# %%
search_google_jobs(search_query="machine learning engineer", next_page_token=next_page_token, verbose=True)
# Out:
# {'title': 'Senior Machine Learning Engineer, Applied ML', 'company_name': 'Robinhood', 'location': 'Menlo Park, CA', 'via': 'Greenhouse', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=Kyuf4_bkbLrcCB3fAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=Kyuf4_bkbLrcCB3fAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728654b9819f3637e4d8e85/images/0237a7282e485314c9401a5417a6670966a3a855094015ec78dffcbba41bc0dc.gif', 'extensions': ['20 days ago', 'Full-time', 'Health insurance', 'Paid time off'], 'detected_extensions': {'posted_at': '20 days ago', 'schedule_type': 'Full-time', 'health_insurance': True, 'paid_time_off': True}, 'description': "About the team + role\n\nThe mission of the Applied Machine Learning team is to provide scalable data and model driven decision making solutions to the various business functions at Robinhood. We aim to create a personalized experience for our users, by helping them discover & engage with the right products & features within Robinhood that they might find most valuable. To accelerate progress, we are also building an accessible model development platform to democratize machine learning practices throughout the company. As we embark on this exciting journey, we are looking for a senior Machine Learning Engineer to join us to make this vision a reality.\n\nWhat you'll do\n\nAs a Machine Learning Engineer on our team, your primary focus will be on the implementation and evaluation of machine learning algorithms through rigorous experimentation and testing methodologies. Your responsibilities will include:\n• Model Development and Implementation: Develop and implement scalable machine learning models focusing on advanced ranking and recommendation systems, including expertise in Collaborative Filtering, Content-Based Filtering, and Hybrid models, alongside proficiency in Learning to Rank (LTR) techniques for effective prioritization. Additionally, design reinforcement learning algorithms and apply multi-armed bandit strategies to optimize decision-making in dynamic environments, balancing exploration and exploitation.\n• A/B Testing and Experimentation: Design and conduct A/B tests to assess the performance of different machine learning models. This includes setting up the test environment, monitoring performance, and analyzing results.\n• Data Analysis and Insight Generation: Analyze experimental data to extract actionable insights. Use statistical techniques to validate the findings and ensure their relevance and accuracy.\n• Cross-Functional Collaboration: Work closely with other engineering teams, data scientists, and the marketing team to integrate machine learning models into the product and ensure they meet business requirements. Present results to different stakeholders.\n• Tooling and Documentation: Build reusable libraries for common machine learning practices. Offer support and guidance to the usage of these tools. Maintain comprehensive documentation of libraries, models, experiments, and findings. .\n\nWhat you bring\n• 5+ years of applied ML experience productionizing ML models with 2+ years focused on recommendations, ranking or personalization projects.\n• A fervent interest in exploring and applying AI and ML technologies.\n• Strive to solve sophisticated engineering problems that drive business objectives.\n• Solid technical foundation enabling active contribution to the design and execution of projects and ideas.\n• Familiarity with architectural frameworks of large, distributed, and high-scale ML applications.\n• Proven experience in ML with a focus on ranking, recommendation systems, multi-objective optimization, and reinforcement learning.\n• Proficiency in Python, SQL, XGboost, PyTorch/TensorFlow.\n• Experience with Spark, Kafka, and Kubernetes is also desirable.\n• Ideally you have experience in the Finance sector.\n\nWhat we offer\n• Market c ...
# {'title': 'Principal Machine Learning Software Engineer', 'company_name': 'Advanced Micro Devices, Inc', 'location': 'Bellevue, WA', 'via': 'AMD Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=1FgqxYd9XVc_zftsAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=1FgqxYd9XVc_zftsAAAAAA%3D%3D', 'extensions': ['Full-time'], 'detected_extensions': {'schedule_type': 'Full-time'}, 'description': "WHAT YOU DO AT AMD CHANGES EVERYTHING\n\nWe care deeply about transforming lives with AMD technology to enrich our industry, our communities, and the world. Our mission is to build great products that accelerate next-generation computing experiences – the building blocks for the data center, artificial intelligence, PCs, gaming and embedded. Underpinning our mission is the AMD culture. We push the limits of innovation to solve the world’s most important challenges. We strive for execution excellence while being direct, humble, collaborative, and inclusive of diverse perspectives.\n\nAMD together we advance_\n\nPrincipal Machine Learning Software Engineer\n• Job Description\n\nAs a Machine Learning Engineer specializing in low-level performance optimization, you will play a critical role in helping our customers to advance AMD-based machine learning infrastructure and ensuring the efficient deployment of state-of-the-art large models. You will be part of a dynamic team working on groundbreaking projects and will be responsible for optimizing model execution, including GPU kernels, both for inference and training, in a multi-GPU and multi-node environment. Your contributions will directly impact our ability to deliver cutting-edge AI solutions efficiently and at scale.\n\nKey Responsibilities\n• GPU Kernel Optimization: Develop and optimize low-level GPU kernels to accelerate inference and training of large machine learning models. Maximize the computational efficiency and reduce execution time while ensuring model accuracy.\n• Multi-GPU and Multi-Node Optimization: Design and implement strategies for distributed model training and inference across multiple GPUs and nodes. Address data parallelism and model parallelism challenges to fully utilize available resources.\n• Performance Profiling: Profile and analyze system and application performance to identify bottlenecks and areas for improvement. Use profiling tools to understand and optimize hardware resource utilization.\n• Parallel Computing: Leverage parallel computing techniques to improve the scalability and performance of machine learning workloads. Implement multi-threading and GPU synchronization techniques.\n• Model Quantization: Explore and apply model quantization techniques to reduce memory and computation overhead, especially for edge and cloud deployment.\n• Benchmarking and Testing: Develop benchmarks and testing procedures to assess the performance and stability of optimized models and frameworks. Ensure that the solutions meet or exceed the defined performance criteria.\n• Collaboration: Collaborate closely with machine learning researchers, software engineers, and infrastructure teams to integrate optimized kernels and solutions into production systems.\n• Documentation: Create detailed documentation of optimizations, best practices, and implementation guidelines to facilitate knowledge sharing and maintainable code.\n\nQualifications\n• A Bachelor, Master's or Ph.D. in Computer Science, Electrical Engineering, or a related field or equivalent practical experience.\n• Solid understanding of GPU accelerators like ONNX, DeepSpeed, VLLM\n• Strong experience in low-level GPU kernel optimization.\n• Proficiency in CUDA and GPU programming.\n• Experience with distributed computing and multi-GPU environments.\n• Proficiency in performance profiling and optimization tools.\n• Solid programming skills in Python and/or C++.\n• Experience with deep learning fr ...
# {'title': 'Senior Machine Learning Engineer', 'company_name': 'Capital One', 'location': 'York, PA', 'via': 'Recruiter Jobs', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=DYb8Mv2QpMRq7ikjAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=DYb8Mv2QpMRq7ikjAAAAAA%3D%3D', 'extensions': ['3 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '3 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "Center 1 (19052), United States of America, McLean, VirginiaSenior Machine Learning EngineerAs a Capital One Machine Learning Engineer (MLE), you'll be part of an Agile team dedicated to productionizing machine learning applications and systems at scale. You’ll participate in the detailed technical design, development, and implementation of machine learning applications using existing and emerging technology platforms. You’ll focus on machine learning architectural design, develop and review model and application code, and ensure high availability and performance of our machine learning applications. You'll have the opportunity to continuously learn and apply the latest innovations and best practices in machine learning engineering. What you’ll do in the role: The MLE role overlaps with many disciplines, such as Ops, Modeling, and Data Engineering. In this role, you'll be expected to perform many ML engineering activities, including one or more of the following:Design, build, and/or deliver ML models and components that solve real-world business problems, while working in collaboration with the Product and Data Science teams. Inform your ML infrastructure decisions using your understanding of ML modeling techniques and issues, including choice of model, data, and feature selection, model training, hyperparameter tuning, dimensionality, bias/variance, and validation).Solve complex problems by writing and testing application code, developing and validating ML models, and automating tests and deployment. Collaborate as part of a cross-functional Agile team to create and enhance software that enables state-of-the-art big data and ML applications. Retrain, maintain, and monitor models in production.Leverage or build cloud-based architectures, technologies, and/or platforms to deliver optimized ML models at scale.Construct optimized data pipelines to feed ML models. Leverage continuous integration and continuous deployment best practices, including test automation and monitoring, to ensure successful deployment of ML models and application code. Ensure all code is well-managed to reduce vulnerabilities, models are well-governed from a risk perspective, and the ML follows best practices in Responsible and Explainable AI. Use programming languages like Python, Scala, or Java. Basic Qualifications:Bachelor’s degreeAt least 4 years of experience programming with Python, Scala, or Java (Internship experience does not apply)At least 3 years of experience designing and building data-intensive solutions using distributed computing At least 2 years of on-the-job experience with an industry recognized ML frameworks (scikit-learn, PyTorch, Dask, Spark, or TensorFlow) At least 1 year of experience productionizing, monitoring, and maintaining models Preferred Qualifications:1+ years of experience building, scaling, and optimizing ML systems1+ years of experience with data gathering and preparation for ML models2+ years of experience developing performant, resilient, and maintainable codeExperience developing and deploying ML solutions in a public cloud such as AWS, Azure, or Google Cloud PlatformMaster's or doctoral degree in computer science, electrical engineering, mathematics, or a similar field 3+ years of experience with distributed file systems or multi-node database paradigmsContributed to open source ML software Authored/co-authored a paper on a ML technique, model, or  ...
# {'title': 'Senior Software Engineer - Machine Learning', 'company_name': 'FIS Global', 'location': 'Seattle, WA', 'via': 'FIS Global', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=elqcXDbPqMciM7c4AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=elqcXDbPqMciM7c4AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728654b9819f3637e4d8e85/images/0237a7282e48531465d5c25a331f4a64e47a2c249f62a970fb12d001f233fa02.gif', 'extensions': ['6 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '6 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': "Position Type :\nFull time\n\nType Of Hire :\nExperienced (relevant combo of work and education)\n\nTravel Percentage :\n1 - 5%\n\nJob Description\n\nAs the world works and lives faster, FIS is leading the way. Our fintech solutions touch nearly every market, company and person on the planet. Our teams are inclusive and diverse. Our colleagues work together and celebrate together. If you want to advance the world of fintech, we’d like to ask you: Are you FIS?\n\nAbout the team:\n\nFIS technology processes more than $40 Trillion per year and enables 95% of the world’s leading banks. Our Fraud Intelligence team is on the cutting edge of data science and machine learning technology that detects and prevents fraud on a global scale. As a Machine Learning Data Engineer, you will tackle challenges ranging from identity theft to credit card fraud, to money laundering, and more. The technology you build will protect individuals, businesses and financial institutions from fraudsters ranging from individuals up to multinational organized crime rings. The fraud prevention space is fast-paced and rapidly changing. You will work cross-discipline with data scientists, analytics, product, and more. Our ideal candidate not only brings technical skills to the table but has the appetite to dig into deeply complex problems, while learning new skills along the way. We are leading the way and leveraging our wealth of data to create best-in-class solutions.\n\nAbout the role:\n\nWe are looking for a Senior Machine Learning Engineer to help us build a brand-new financial technology platform for the future. We look for people who operate like owners, who loves to learn, have grit, and operate with integrity and empathy. You're encouraged to apply even if your experience doesn't precisely match the job description. Your skills and passion will stand out — and set you apart. We welcome diverse perspectives and people who are not afraid to challenge assumptions.\n\nNote: We have a hybrid work environment in our Seattle/Bellevue, office unless the role or business dictates otherwise.\n\nWhat you will be doing:\n• Understand business objectives, product requirements and develop ML algorithms that achieve them.\n• Build Prototypes, and proof of concepts to determine feasibility, then drive data-based decisions.\n• Run experiments to assess performance and improvements.\n• Provide ideas and alternatives to drive a product/feature.\n• Define data and feature validation strategies.\n• Deploy models to production systems and operate them including monitoring and troubleshooting\n• Design, build, and manage the data pipelines and infrastructure that collect, store, and process large volumes of transactional and customer data from various sources.\n• Develop, deploy, and scale machine learning models and applications in production and lower environments\n• Ensure data quality, security and availability for the data, notebooks, models, experiments, and applications.\n• Integrate ML models with the SaaS platform and other services and tools, such as the model registry, feature store, data lake, and event streams.\n• Collaborate with data scientists to develop and test machine learning models.\n• Drive code reviews to ensure code quality, mainta ...
# {'title': 'Machine Learning Engineer II', 'company_name': 'Grainger', 'location': 'Lake Forest, IL', 'via': 'Built In Chicago', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=EdHcoai7lUX26NrsAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=EdHcoai7lUX26NrsAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728654b9819f3637e4d8e85/images/0237a7282e4853142898ec6270a89ab0ce963402baf9abb5aef24903d828106e.gif', 'extensions': ['21 days ago', 'Full-time', 'Health insurance', 'Paid time off', 'Dental insurance'], 'detected_extensions': {'posted_at': '21 days ago', 'schedule_type': 'Full-time', 'health_insurance': True, 'paid_time_off': True, 'dental_coverage': True}, 'description': "Work Location Type: Hybrid\nAs a leading industrial distributor with operations primarily in North America, Japan and the United Kingdom, We Keep The World Working® by serving more than 4.5 million customers worldwide with products delivered through innovative technology and deep customer relationships. With 2023 sales of $16.5 billion, we're dedicated to providing value for customers, fostering an engaging culture for team members and driving strong financial results.\nOur welcoming workplace enables you to learn, grow and make a difference by keeping businesses running and their people safe. As a 2024 Glassdoor Best Place to Work and a Great Place to Work-Certified™ company, we're looking for passionate people to join our team as we continue leading the industry over our next 100 years.\nPosition Details:\nGrainger's inventory planning team manages over 10 million SKU's and nearly $2 billion in inventory across 500 DC's and branches in North America. We're hiring a Machine Learning Engineer II, Inventory Optimization and Advanced Analytics to support and develop solutions to support a team of data scientist to make analytics-based decisions on where, when, and how much inventory is needed to satisfy customers' needs. You will report to the Manager, Machine Learning Engineer, Inventory Optimization & Advanced Analytics. The position will be hybrid in Lake Forest or Chicago 3 days per week.\nYou Will:\n• Create scalable, efficient, automated processes for large-scale data analyses, model development, model validation and deployment\n• Oversee machine learning solutions, collaborating with data scientists to foster ongoing continuous improvement\n• Explore emerging technologies to evaluate their potential application to our team's objectives, and responsible for the deployment of innovative solutions that align with our strategic goals\n• Automate critical system operations, design robust ETL pipelines, and develop web applications that enable stakeholders to effectively interact with and utilize our ML and ERP systems\n\nYou Have:\n• 4+ years of experience deploying and maintaining production machine learning solutions with Python\n• 2+ years of experience AWS products (s3, ECR, Secrets Manager)\n• Follow software engineering practices and use version control and CI/CD tools (GitHub, GitHub Actions)\n• Proficient in usage of databases (Snowflake, In memory DB's,non-Relational DB's ) and querying languages (e.g. SQL)\n• Experience in working data streaming platform like Kafka\n• Experience working in containerization ecosystems (Kubernetes, Docker)\n• Familiarity with machine learning models and concepts (time series forecasting, clustering)\n• Experience automating workflows using orchestration (Astronomer, Airflow)\n\nOur Benefits:\nWith benefits starting day one, Grainger is committed to your safety, health, and wellbeing. Our programs provide alternatives to meet our team members' individual needs. Check out some of the rewards available to you at Grainger: Medical, dental, vision, and life insurance plans\nPaid time off (PTO) and 6 company holidays per year\nAutomatic 6% 401(k) company contribution each pay period\nEmployee  ...
# {'title': 'Senior Machine Learning Engineer - AI Startup', 'company_name': 'Jaxon AI', 'location': 'Boston, MA', 'via': 'LinkedIn', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=yPg6aPDBqz6DLaV2AAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=yPg6aPDBqz6DLaV2AAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728654b9819f3637e4d8e85/images/0237a7282e4853141835aadf651fe0dcc898c81f6eaf22c849bae0ef8d0e3cee.gif', 'extensions': ['4 days ago', '160K–200K a year', 'Full-time', 'Dental insurance', 'Paid time off', 'Health insurance'], 'detected_extensions': {'posted_at': '4 days ago', 'salary': '160K–200K a year', 'schedule_type': 'Full-time', 'dental_coverage': True, 'paid_time_off': True, 'health_insurance': True}, 'description': 'Position Name: Machine Learning Engineer\n\nLocation: Lincoln, MA or Remote\n\nEmployment Type: Full-time\n\nCitizenship: US Citizens only\n\nNotes: Direct Hire. No third-party assistance is approved for this role.\n\nAbout The Job: At Jaxon, we are on a mission to make AI trustworthy. The adoption of large language models (LLMs) in corporate settings is hindered by the “hallucination problem,” where AI models produce inaccurate or entirely fabricated responses. For regulated industries and high-risk applications, this issue is preventing LLM use altogether. This role is crucial in overcoming these challenges.\n\nAs a Machine Learning Engineer at Jaxon, you will be responsible for developing and implementing machine learning models and algorithms to create more reliable AI systems. You will play a key role in delivering complex AI-driven solutions for customers, with a particular focus on defense applications as Jaxon is dual-use.\n\nWe have a patent pending product, Domain-Specific AI Logic (DSAIL), that forms the basis of most of our deployments. This role will be focused on increasing security and reliability for our customers through implementing DSAIL and building on its capabilities. A particular emphasis is placed on addressing the fundamental limitations of LLMs – they don’t understand context and logical reasoning. Once an LLM deviates from the right path, errors are more likely to occur. Training an AI away from this type of yes/no logic and into more human-like reasoning is at the core of this position.\n\nThe Basics Of This Role Requires The Ability To\n• Collaborate Across Teams: Work with cross-functional teams to integrate ML models into our existing systems and workflows, enhancing product capabilities.\n• Optimize Data Processing and Model Performance: Conduct comprehensive data management including preprocessing, feature engineering, and model evaluation to improve accuracy and efficiency.\n• Technical Proficiency: Demonstrate solid machine learning engineering experience, particularly with NLP applications and unstructured data in a cloud environment. Fluency in Python is essential.\n• Understand Machine Learning Models: Needs to be intimately familiar with the process, but deploying ML models will not be a regular part of the job.\n• Soft Skills:\n• Able to context switch as needed\n• Able to compartmentalize different projects with different goals\n• Able to communicate clearly and precisely - not just abstractions and "lines-and-boxes"\n\nSpecific Technologies\n• Docker, Docker Compose\n• Python\n• Python Data Science Stack - NumPy, Pandas, Scikit Learn, Various deep learning packages\n• Familiarity with calling web API\'s and making web API\'s\n• Familiarity with modular architectures - IPC, publish-subscribe, etc…\n\nNice-To-Haves\n• Familiarity with predicate logic\n• Familiarity with Extended Backus-Naur Form (EBNF) notation for language grammars\n• Lisp languages\n\nAbout Jaxon: Jaxon is a leading provider of machine learning and artificial intelligence solutions. We are committed to helping our customers solve complex problems with AI. Our products a ...
# {'title': 'Principal Machine Learning Engineer', 'company_name': 'Zoox', 'location': 'Foster City, CA', 'via': 'SimplyHired', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=inEEjn2F59lGvcwLAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=inEEjn2F59lGvcwLAAAAAA%3D%3D', 'thumbnail': 'https://serpapi.com/searches/6728654b9819f3637e4d8e85/images/0237a7282e485314677745485eafcfa8c3173ed4cf96cedb839bc2e22d277981.gif', 'extensions': ['6 days ago', 'Full-time', 'Dental insurance', 'Paid time off', 'Health insurance'], 'detected_extensions': {'posted_at': '6 days ago', 'schedule_type': 'Full-time', 'dental_coverage': True, 'paid_time_off': True, 'health_insurance': True}, 'description': 'The Prediction & Behavior ML team is responsible for developing machine learning (ML) algorithms that learn and predict behaviors from data, applying them both on-vehicle to influence driving behavior and off-vehicle to provide ML capabilities to simulation and validation. Given the tight integration of behavior forecasting and motion planning, our team collaborates closely with the Planner team to advance overall vehicle behavior. We also work closely with our Perception, Simulation, and Systems Engineering teams to accelerate our ability to validate our driving performance.\n\nAs a Principal ML Engineer, you will lead the development of machine learning algorithms that can range from influence from onboard autonomy to offboard autonomy and validation. You will collaborate closely with teams specializing in Perception, Simulation, and Safety Validation, influencing our overall technical stack. Your role will look at problems in a way that crosses team boundaries to prototype new approaches that influence the long term technical direction of multiple organizations within the company. The impact of the role can be in the form of impacting immediate company milestones to leading forward-looking exploratory projects.\n\nResponsibilities\n• *\nDevelop new algorithms to model the future behavior of our own vehicle’s future actions, both in predicting our driving trajectories and estimating their quality in relation to our goals of safety, progress, and comfort\n• Build the foundation models for the on-vehicle and offline applications\n• Develop new algorithms to apply generative deep learning to simulation to improve the realism of our offline validation systems\n• Leverage our large-scale machine learning infrastructure to discover new solutions and push the boundaries of the field\n• Provide technical mentorship to the broader group of ML developers at Zoox\n• Collaborate with engineers on Perception, Planning, and Simulation to solve the overall Autonomous Driving problem in complex urban environments\n\nQualifications\n• *\nBS, MS, or PhD degree in computer science or related field\n• Experience with training and deploying Deep Learning models\n• Experience with production Machine Learning pipelines: dataset creation, training frameworks, metrics pipelines\n• Fluency in C++ or Fluency in Python with a basic understanding of C++\n• Extensive experience with programming and algorithm design\n• Strong mathematics skills\n• 10+ years of experience\n\nBonus Qualification\n• *\nConference or Journal publications in Machine Learning or Robotics related venues\n• Prior experience with Prediction and/or autonomous vehicles or robotics in general\n\nCompensation\n\nThere are three major components to compensation for this position: salary, Amazon Restricted Stock Units (RSUs), and Zoox Stock Appreciation Rights. The salary will range from $296,000-$451,000. A sign-on bonus may be part of a compensation package. Compensation will vary based on geographic location, job-related knowledge, skills, and experience.\n\nZoox also offers a comprehensive package of benefits including paid time off (e.g. sick leave, vacation, bereavement), unpaid time of ...
# {'title': 'Lead Machine Learning Engineer', 'company_name': 'Disney Entertainment & ESPN Technology', 'location': 'Seattle, WA (+3 others)', 'via': 'Disney Careers', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=machine+learning+engineer&htidocid=SpZQhOtFQmOdwjcoAAAAAA%3D%3D&hl=en-US&shndl=-1&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=machine+learning+engineer&htidocid=SpZQhOtFQmOdwjcoAAAAAA%3D%3D', 'extensions': ['26 days ago', 'Full-time', 'Health insurance'], 'detected_extensions': {'posted_at': '26 days ago', 'schedule_type': 'Full-time', 'health_insurance': True}, 'description': 'Disney Entertainment & ESPN Technology\n\nOn any given day at Disney Entertainment & ESPN Technology, we are reimagining ways to create magical viewing experiences for the world’s most beloved stories while also transforming Disney’s media business for the future. Whether that is evolving our streaming and digital products in new and immersive ways, powering worldwide advertising and distribution to maximize flexibility and efficiency, or delivering Disney’s unmatched entertainment and sports content, every day is a moment to make a difference to partners and to hundreds of millions of people around the world.\n\nA few reasons why we think you would love working for Disney Entertainment & ESPN Technology\n• Building the future of Disney’s media business: DE&E (Disney Entertainment & ESPN) Technologists are designing and building the infrastructure that will power Disney’s media, advertising, and distribution businesses for years to come.\n• Reach & Scale: The products and platforms this group builds and operates delight millions of consumers every minute of every day – from Disney+ and Hulu, to ABC News and Entertainment, to ESPN and ESPN+, and much more.\n• Innovation: We develop and execute groundbreaking products and techniques that shape industry norms and enhance how audiences experience sports, entertainment & news.\n\nThe vision of the Machine Learning (ML) Engineering team at Disney is to drive and enable ML usage across several domains in heterogeneous language environments and at all stages of a project’s life cycle, including ad-hoc exploration, preparing training data, model development, and robust production deployment. The team is invested in continual innovation on the ML infrastructure itself to carefully orchestrate a continuous cycle of learning, inference, and observation while also maintaining high system availability and reliability. We seek to maximize the positive business impact of all ML at Disney streaming by supporting key product functions like personalization and recommendation, fraud and abuse prevention, capacity planning, subscriber growth and lifecycle intelligence, and so on.\n\nIn this role You will be expected to lead recommendation and personalization algorithm research, development, implementation, and optimization for product areas, and work on event and context processors to federate data, infrastructure and tooling to enable event-driven ML pipelines. You will own and expand part of our central feature store that powers ML use cases in domains like recommendations, search and fraud. You will work on cross-functional projects and push the envelope on data and ML infrastructure.\n\nWhat You Will Do\n• Algorithm Development and Maintenance: Utilize cutting edge machine learning methods to deploy and develop algorithms for personalization, recommendation, and other predictive systems; maintain algorithms deployed to production and be the point person in explaining methodologies to technical and non-technical teams\n• Feature Engineering and Optimization: Develop and maintain ETL pipelines using orchestration tools such as Airflow and Jenkins; deploy scalable streaming and batch data pipelines to support petabyte scale datasets\n• Development Best Practices: Maintain existing and establish new algorithm development, testing, and deployment standards\n• Collaborate with product and b ...
# '...'

# %%
for result in result_dict['jobs_results']:
    print(result["title"], result["company_name"])
# Out:
# Product Manager, Data Science & Analytics (Remote) The Home Depot
# Data Scientist, Paramount Advertising Paramount
# Manager Data Scientist Capital One
# Data Science Solution Specialist - Generative AI Deloitte
# Senior Data Scientist, ASE iCloud Data Organization [Executive Communications] Apple
# (USA) Senior, Data Scientist (Computer Vision Engineer) Walmart Inc.
# Public Notice for Direct Hire (STEM) - Data Scientist Public Health
# Data Scientist , Global FP&A Technology Amazon.com Services LLC
# Data Scientist Intern United States Cisco
# Senior Director of Data Science Formation Bio

# %% [markdown]
# ## Iterate over job titles
#
# These titles reflect a wide range of roles that leverage data science and machine learning skills in various industries and specialties.
#
# - Data Scientist
# - Machine Learning Engineer
# - Artificial Intelligence Specialist
# - Data Analyst
# - Business Intelligence Analyst
# - Research Scientist (AI/ML)
# - Deep Learning Engineer
# - NLP Engineer (Natural Language Processing)
# - Computer Vision Engineer
# - Data Engineer
# - Applied Scientist
# - Quantitative Analyst (Quant)
# - Predictive Modeler
# - AI Solutions Architect
# - Statistician
# - Big Data Engineer
# - Data Science Consultant
# - Automation Engineer
# - Analytics Manager
# - Decision Scientist
# - Operations Research Analyst
# - Robotics Engineer
# - Bioinformatics Data Scientist
# - Healthcare Data Analyst
# - Financial Data Scientist
# - Customer Insights Analyst
# - Marketing Data Analyst
# - Data Strategy Manager
# - Cloud AI Engineer
# - Computational Scientist
# - Fraud Detection Specialist
# - Risk Analyst
# - Data Architect
# - Algorithm Engineer

# %% [markdown]
# For each keyword, do three searches, using pagination, this will result in around 30 jobs per keyword (assuming there are at least 30 jobs for the particular keyword), save each search results to a file.
#
# Note, just to be safe, wait a one second between each request e.g. using `time.sleep(1)`

# %%
job_titles = [
    "Data Scientist",
    "Machine Learning Engineer",
    "Artificial Intelligence Specialist",
    "Data Analyst",
    "Business Intelligence Analyst",
    "Research Scientist (AI-ML)",
    "Deep Learning Engineer",
    "NLP Engineer (Natural Language Processing)",
    "Computer Vision Engineer",
    "Data Engineer",
    "Applied Scientist",
    "Quantitative Analyst (Quant)",
    "AI Solutions Architect",
    "Statistician",
    "Big Data Engineer",
    "Data Science Consultant",
    "Automation Engineer",
    "Analytics Manager",
    "Operations Research Analyst",
    "Robotics Engineer",
    "Bioinformatics Data Scientist",
    "Financial Data Scientist",
    "Customer Insights Analyst",
    "Marketing Data Analyst",
    "Data Strategy Manager",
    "Cloud AI Engineer",
    "Computational Scientist",
    "Fraud Detection Specialist",
    "Risk Analyst",
    "Data Architect"
]

# print(len(job_titles)*3)

# %% [markdown]
# Now insert code to iterate over the job titles, and perform the searches.
#
# Be very careful, this needs to be 100% correct before running it, otherwise you will burn through your free searches.
#
# I would recommend doing just one iteration of the loop as a trial run, if that looks good, then do do the next iteration and carefully check the results, if everything looks good then do remaining 28 iterations.
#
# Note: sometimes the Pagination will return less than 10 results, so you may end up with slightly less than 30 results per keyword, e.g. 25 to 30
#
# Remember to clean the job tiles to remove any characters like spaces, `/` or `()`

# %%
# INSERT CODE HERE
import time
def job_search(job_title):
    for title in job_title:
        clean_title = title.replace(" ", "_").replace("/", "_").replace("(", "").replace(")", "")
        print(f"\n---------------\n{title}")
        next_page_token = None
        for num in range(3):  
            print(f"SEARCH- {num}")
            next_page_token,jobs_results = search_google_jobs(clean_title, next_page_token)

            if jobs_results:
                for job in jobs_results:
                    print(f"{job['title']} : {job['company_name']}")
            else:
                print(f"No results found for '{title}' on SEARCH- {num}.")

            if not next_page_token:
                break  

            time.sleep(1) 


job_search(job_titles)
# Out:
# ---------------
# Data Scientist
# SEARCH- 0
# Data Scientist II : Cencora
# Lead Analyst – Data Science : Colorado Rockies
# Technical Intern - Data Scientist : BAE Systems
# Data Scientist- REMOTE : Prime Therapeutics
# Data Scientist : VIZIO, Inc.
# Data Scientist Principal (REMOTE) – Life Insurance Company : USAA
# Data Scientist - Clearance Required : Logistics Management Institute
# Data Scientist II : NSA Storage
# Principal Data Scientist : Self Financial
# Data Scientist, R&D : Eight Sleep
# SEARCH- 1
# Lead Data Scientist : Vendavo
# Full Stack Data Scientist : Cardinal Health
# Staff LLM Data Scientist : TIFIN
# Principal Data Scientist - Service Enablement Analytics : Atlassian
# Wildfire Data Scientist : Xcel Energy
# Cleared Data Scientist (All Levels) : Noblis
# Data Scientist II : Grubhub Holdings Inc.
# Principal Data Scientist : Sovrn
# Data Scientist : Partner Opportunities
# SEARCH- 2
# Data Scientist II (NLP Required) : CareSource
# Data Scientist : NSA Storage
# Technical Intern - Data Scientist : BAE Systems, Inc.
# Data Scientist II : MIN Medtronic Minimed Inc.
# Senior Data Scientist, Performance Analytics : ENGIE
# Staff Data Scientist - Remote : Empower Finance
# Lead, Data Scientist : hims & hers
# Senior Data Scientist - AI CoE : Cardinal Health
# Data Scientist I - ML : Cotiviti
# Data Scientist, 3+ Years of Experience : Snap Inc.
#
# ---------------
# Machine Learning Engineer
# SEARCH- 0
# Machine Learning Engineer : Apple
# Lead Machine Learning Engineer - Supply Chain : Nike
# Machine Learning Engineer III : Chewy
# Machine Learning Engineer, OS Intelligence : Apple
# Scientific Programming and Machine Learning Engineer : Leidos
# Senior Machine Learning Engineer : Capital One
# Principal Machine Learning Engineer : Disney
# Senior Machine Learning Engineer, Applied ML : Robinhood
# Senior Machine Learning Engineer (Python, Spark/Dask, MLOPS) : RemoteWorker CA
# Oracle Restaurants - Machine Learning Engineer : Oracle
# SEARCH- 1
# Machine Learning/AI Engineer : Keysight Technologies, Inc.
# Machine Learning Lead : Tekfortune
# Principal Machine Learning Software Engineer : Advanced Micro Devices, Inc
# Senior Software Engineer - Machine Learning : FIS Global
# Senior AI / ML Engineer (REMOTE) : HPE
# Machine Learning Engineer II : Grainger
# Engineer – Machine Learning (ML)/Artificial Intelligence : Parsons Corporation
# Lead Machine Learning Engineer : Disney Entertainment & ESPN Technology
# Principal Machine Learning Engineer : Zoox
# SEARCH- 2
# Scientific Machine Learning Software Developer : Johns Hopkins Applied Physics Laboratory
# Machine Learning Engineer : Empower AI Inc.
# Distinguished Machine Learning Engineer : Capital One
# Software Engineer, Machine Learning : CLEAR - Corporate
# Machine Learning Engineer, Federal : Scale AI
# Machine Learning Engineer (MLOps) : DeepRec.ai
# Staff Machine Learning Operations (MLOps) Engineer : Grubhub
# AIML - ML Engineer, Machine Learning Platform & Infra : Apple
# Principal Machine Learning Engineer : McKesson Corporation
#
# ---------------
# Artificial Intelligence Specialist
# SEARCH- 0
# Specialist in Artificial Intelligence & Educational Technology for Veterinary & Biomedical Sciences : Colorado State University
# Digital Health Specialist - Generative Artificial Intelligence : FDA
# AI Development Specialist : Partner Opportunities
# Senior IT Specialist (Artificial Intelligence - AI/INFOSEC) - DIRECT HIRE : US Federal Transit Administration
# PC AI Sales Specialist - FL/GA : HPE
# AI Technical Specialist : AMD
# Artificial Intelligence Threat Analyst / Lead Artificial Intelligence Threat Analyst : UM28 University of Baltimore (UBALT)
# AI Data Specialist : Deloitte
# AI Math Specialist : Outlier
# Data Analyst and Machine Learning Specialist : University of Maryland, Baltimore County
# SEARCH- 1
# Technical Solutions Specialist : Figure Eight Federal
# AI API specialist to integrate TypingMind into Claude AI and make it usable : Upwork
# Solutions Architect, Generative AI Specialist : 2100 NVIDIA USA
# Machine Learning Specialist, Trilogy (Remote) - $100,000/year USD : Crossover
# Expert AI/Machine Learning Specialist Needed : Upwork
# AI and Information Security Analyst : RAND
# AI Language Specialist : Outlier
# HPC/AI Sales Specialist, Federal : HPE
# AI specialist to setup make.com scenarios to process Google Sheets with AI : Upwork
# SEARCH- 2
# AI Training Analyst : Outlier
# AI & LLM Specialists : Motion Recruitment
# Deloitte Consulting - Artificial Intelligence & Data Engineering Analyst : Deloitte
# Gen AI Specialist : Upwork
# Senior Technology Specialist Data & AI : Microsoft
# AI Specialist for Smart Recruitment & Body Language Detection : Upwork
# Artificial Intelligence Governance Lead, Senior Advisor - Nationwide : Cardinal Health
# Responsible AI Advisor Specialist : Accenture
# AI Data Trainer - Mathematics Specialist : Outlier
# AI Data Trainer - Mathematics Specialist : Outlier
#
# ---------------
# Data Analyst
# SEARCH- 0
# [Full Remote] HR Data Analyst : Joinrs US
# Data Analyst Engineer : Peraton
# Data Analyst II : CORE Electric Cooperative
# Data Analyst : Falcon School District 49
# Jr. Data Analyst (Remote) : SynergisticIT
# Senior Technical Data Analyst : GHX
# Investment Analytics Data Analyst : Thornburg Investment Management
# Data Analyst / Reporting Specialist : High Counry Search
# Data Analyst-VA : ATC
# Sr. Data Analyst : Xcel Energy Services
# SEARCH- 1
# Ad Ops Data Analyst : AdMedia
# Data Analyst - Full Time : Progressive Insurance
# Senior Data Analyst : AgriSompo North America
# Data Analyst, Operations : Sovrn
# Lead Analyst, Data Quality Analytics and Performance Improvement- Remote : Molina Talent Acquisition
# Entry Level Data/Business Analyst : SynergisticIT
# Data Analyst(Testing) : Capgemini
# Data Analyst (Remote) : NuView
# Senior Manager, Regulatory Data Analyst : Charles Schwab
# Data Analyst (Marketing) : Techint Labs
# SEARCH- 2
# Data Analyst for Investment Opportunity Analysis : Upwork
# Senior Data Analyst - Customer Service : BetMGM LLC
# Principal Data Analyst, General : Flex
# Graduate Data Analyst : DISH Network
# Finance Systems Data Analyst : Colorado College
# Data Analyst - Pay Equity : Ogletree Deakins
#
# ---------------
# Business Intelligence Analyst
# SEARCH- 0
# Business Intelligence Analyst, Senior : UPMC
# Business Intelligence Analyst : Partner Colorado Credit Union
# Business Intelligence Analyst - Remote : Center for Internet Security, Inc.
# Business Intelligence Analyst II : Sovos Compliance
# Business Intelligence Analyst-OBGYN : Vanderbilt University Medical Center
# Sr BI Analyst : Blue Cross NC
# Business Intelligence Analyst : Donor Alliance, Inc.
# Business Intelligence Analyst : CenterWell
# BI Analyst : University of Colorado Denver
# Sr Analyst, Business Intelligence : T-Mobile USA
# SEARCH- 1
# Business Intelligence Analyst : Gaia
# Sr Business Intelligence Analyst, Internet Performance Reporting : TMobile
# Staff Strategy and Business Intelligence Analyst : Sunrun
# Business Intelligence Analyst : Domotz
# Sr. Business Intelligence Analyst : 100
# Business Intelligence Analyst III : Blue Origin, LLC
# Senior Business Intelligence Analyst : CenterWell
# Business Intelligence Analyst III : UCLA Health Systems
# SEARCH- 2
# Business Intelligence Analyst II - P&C Distribution & Service (DnS) : USAA
# Business Intelligence Analyst 3 : Five Cubes
# Business Intelligence Report Developer/Analyst : Ingevity Corporation
# Data Analyst - Business Intelligence : PDS Inc, LLC
# Sr. FP&A Business Intelligence Analyst : Aegon
# Intelligence analyst : Mediabistro
# Sales Business Intelligence Analyst : The Mom Project
# Analyst - Healthcare Informatics and Business Intelligence : Waymark
# Senior Business Intelligence Analyst - Clinical (Patient Safety / Quality) : Memorial Sloan Kettering Cancer Center
# Senior/Principal Business Intelligence Analyst : Billings Clinic
#
# ---------------
# Research Scientist (AI-ML)
# SEARCH- 0
# Research Scientist, AI and ML : Oak Ridge National Laboratory
# Principal Research Scientist II, AI / ML Team Lead : AbbVie
# AIML - Natural Language Modeling Research Scientist, Siri and Information Intelligence : Apple
# AI Research Scientist, Neuromotor Interfaces, ML & Signal Proc : Meta
# AI Research Scientist : Zoom
# AI/ML Research Engineer : Lockheed Martin
# Research Scientist: AI/ML Mechanical Modeling and Characterization : Eqlipse Technologies LLC
# Senior Scientist, Artificial Intelligence/Machine Learning, Foundational ML (gCS, BRAID) : Genentech
# Senior AI Research Scientist : T Rowe Price
# AIML - Generative Foundation Model/LLM Research Scientist, MLR : Apple
# SEARCH- 1
# Machine Learning Research Scientist : Johns Hopkins Applied Physics Laboratory
# Research Scientist, AI & Machine Learning (PhD) : Oracle
# Data Scientist - AI/ML : Stanford Health Care
# Expert AI/ML Applied Scientist - Generative AI ( Seattle & Bay Area) : SAP
# Senior Research Scientist,  AI x Imaging : Chan Zuckerberg Initiative
# AIML - ML Research Engineer or Scientist : Apple
# Senior AI Research Scientist/Specialist, Foundation Models : Merck
# Staff AI Scientist : GE HEALTHCARE
# 1910 Genetics : 1910 Genetics
# SEARCH- 2
# Machine Learning Researcher : Johns Hopkins Applied Physics Laboratory
# AI Research Scientist - Computer Vision (Technical Leadership) : Meta
# AI/ML Research Scientist/Engineer : Collinear AI
# Postdoctoral Research Associate - Scientific Machine Learning : Oak Ridge National Laboratory
# AI Research Scientist : Collaborative Robotics
# Research Scientist, Systems ML – SW/HW Co-Design – Inference : MetaPhase Consulting
# AIML - Machine Learning Researcher, Foundation Models : Apple
# ML Research Scientist (Senior / Staff / Principal) : Genesis Therapeutics
#
# ---------------
# Deep Learning Engineer
# SEARCH- 0
# Deep Learning Software Engineer - AI Models : Advanced Micro Devices, Inc
# Senior Deep Learning Engineer, Agentic AI : 2100 NVIDIA USA
# Deep Learning Engineer : QuantCo
# Deep Learning Engineer - Distributed Task-Based Backends : 2100 NVIDIA USA
# Machine Learning Engineer, OS Intelligence : Apple
# AI & Machine Learning Engineer : SynergisticIT
# Planning & Prediction Deep Learning Engineer : Leading EV Manufacturer
# Distinguished Machine Learning Engineer : Capital One
# Principal Machine Learning Engineer (AI Research) : Palo Alto Networks
# Senior Deep Learning Systems Software Engineer - AI Infrastructure : 2100 NVIDIA USA
# SEARCH- 1
# Senior Deep Learning Algorithm Engineer : NVIDIA Corporation
# Senior Machine Learning Engineer - Applied AI : Uber
# Machine Learning Engineer, Responsible AI : Grammarly
# Deep Learning Engineer : Matroid
# Machine Learning Engineer- Aerospace-REMOTE : Actalent
# AI and Machine Learning Engineer : Hewlett Packard Enterprise
# Staff Machine Learning Engineer - Search : WARNERMEDIA
# SEARCH- 2
# AI and Machine Learning Engineer : SynergisticIT
# Machine Learning Engineer III : Chewy
# Senior Deep Learning Algorithm Engineer - Agentic LLM Inference : Nvidia Corporation
# Senior Deep Learning Engineer : Robotic Research Llc
# Senior Machine Learning Engineer, Applied AI : Argo Labs
# Machine Learning Engineer Intern : Moloco
# Senior Machine Learning Engineer - Apple Watch : Apple
# Machine Learning Engineer : TackleAI
# Staff Machine Learning Engineer, Intelligent Platform : Box
# Lead Machine Learning Engineer : Disney Entertainment & ESPN Technology
#
# ---------------
# NLP Engineer (Natural Language Processing)
# SEARCH- 0
# Research Engineer, Natural Language Generation (NLG) : Apple
# Natural Language Processing Engineer : CodaMetrix
# Natural Language Processing (NLP) Engineer : Unreal Gigs
# Natural Language Processing (NLP) Engineer (The Language Architect) : Unreal Gigs
# Natural Language Processing Engineer- Pipeline : Overture Partners
# Senior Natural Language Processing (NLP) Engineer : Unreal Staffing, Inc
# Natural Language Processing Engineer : Tietronix
# Natural Language Processing (NLP) Engineer : Unreal Gigs
# Natural Language Processing (NLP) Engineer (The Language Architect) : Unreal Gigs
# Looking for AI & Natural Language Processing (NLP) Engineer : Upwork
# SEARCH- 1
# Machine Learning Engineer: Natural Language Processing : Primordial Labs
# Natural Language Processing Scientist (NLP) : Westbourne Quantitative Trading, Technology & Research
# Natural Language Processing (NLP) Engineer : Augment Jobs
# Natural Language Processing Engineer : IBM
# Sr NLP Engineer : Nexus IT
# Natural Language Processing Expert (NLP) - Fort Meade Area : Morfologica
# Senior Staff Engineer, NLP : Samsung Research America
# REMOTE NLP Engineer : Insight Global
# AIML - ML Engineer (NLP/Speech), Siri and Information Intelligence : Apple
# Software Engineer - Natural Language Processing : Josh.ai
# SEARCH- 2
# Senior Natural Language Processing (NLP) Engineer : Roberts Recruiting
# AI/ML NLP Engineer – Hybrid: : BenchmarkIT
# Machine Learning Engineer – Natural Language Processing / Computational Linguist : MoTek Technologies
# NLP Engineer (Remote, NYC, Austin) : Trunk Tools, Inc.
# Senior AI/ML Data Scientist – Natural Language Processing (Hybrid) : Merk
# Lead Natural Language Processing (NLP) Engineer : Unreal Gigs
# Senior Software Engineer, Applied Machine Learning (Semantic Search, Natural Language Processing (NLP), Large Language Models) – Priceless Platform : Mastercard
# Natural Language Processing Specialist : Augment Jobs
# AI/NLP Engineer : Saviance Technologies
#
# ---------------
# Computer Vision Engineer
# SEARCH- 0
# Computer Vision / Machine Learning R&D Engineer : Apple
# Computer Vision Software Engineer : Stellar Science
# Computer Vision Engineer : Mujin
# Computer Vision & ML Engineer, Computer Vision and Remote Sensing : Amazon Web Services (AWS)
# Computer Vision Engineer : Vimaan Robotics
# Computer Vision Engineer : Actalent
# Sr Machine Learning Engineer, Computer Vision, ML Data Platform : Adobe
# Computer Vision Algorithm Engineer - TikTok E-commerce Knowledge Graph : TikTok
# (USA) Senior, Data Scientist (Computer Vision Engineer) : Walmart Inc.
# Computer Vision Engineer : EE Recruiters
# SEARCH- 1
# ERROR FOUND IN SEARCH
# No results found for 'Computer Vision Engineer' on SEARCH- 1.
#
# ---------------
# Data Engineer
# SEARCH- 0
# Data Engineer : Central Intelligence Agency
# Senior Cloud Data Engineer, Reporting & Analytics : CVS Health
# Data Engineer : PepsiCo
# Data Engineer : Walmart
# Senior Data Engineer : Dycom Industries, Inc.
# Data Engineer II : Concero
# Azure Data Engineer/Scienc : Next Gen IT Inc
# Cloud Data Engineer : TEKsystems
# Lead Data Engineer : Capital One
# Software Engineer, Growth Data Engineering : Stripe
# SEARCH- 1
# ERROR FOUND IN SEARCH
# No results found for 'Data Engineer' on SEARCH- 1.
#
# ---------------
# Applied Scientist
# SEARCH- 0
# Applied Scientist : Adobe
# Senior Applied Scientist : Uber
# Applied ML Scientist, Shortcuts : Apple
# Applied Scientist : The AI Institute
# Senior Applied Scientist : Microsoft
# Lead Applied Scientist : Salesforce, Inc.
# Senior Applied Scientist : Amazon.com
# Applied AI Scientist : ZS
# Senior Applied Scientist : Launch Potato
# Applied Scientist Intern - PhD (Remote US - Winter 2025) - 30746 : Splunk
# SEARCH- 1
# Expert AI/ML Applied Scientist - Generative AI ( Seattle & Bay Area) : SAP
# Applied Research Scientist : Advanced Micro Devices, Inc
# Applied Scientist : Amazon Web Services (AWS)
# Applied Scientist : Amazon.com Services LLC
# Applied Scientist II, Amazon Bedrock : Amazon Web Services, Inc.
# Applied Scientist, Amazon : Amazon Business
# Applied Scientist II : Qualtrics
# Principal Applied Scientist : Xero
# Applied Scientist IV : Intelliswift Software Inc
# Sr. Applied Scientist, Ring & Blink AI : Ring
# SEARCH- 2
# Amazon Robotics - Applied Scientist II, Amazon Robotics : Amazon.com Services LLC
# Applied Scientist , Amazon : Amazon Business
# Applied Scientist, Routing and Planning - Science Team : Amazon
# Senior Applied Scientist : Oracle
# Research Scientist, Central Applied Science (PhD) : Meta
# Senior Applied Scientist : Microsoft Corporation
# Senior Applied Scientist : THOMSON REUTERS
# Applied Scientist : Amazon Web Services (AWS)
# Applied Scientist, Amazon Health, Amazon : Amazon.com Services LLC
#
# ---------------
# Quantitative Analyst (Quant)
# SEARCH- 0
# Quantitative Researcher / Quantitative Research Analyst : Citadel
# Quantitative Analyst, Columbia Investment Management Company : Columbia University
# Quantitative Analyst : Magnetar
# Quantitative Analyst : Capstone
# Quantitative Trader (preferred) or Quantitative Analyst - REMOTE! : Infinite Capital
# Principal Quantitative Analyst - CMA Predictive Analytics : Capital One
# Quantitative Research Analyst : Verition Group LLC
# Quantitative Analyst : CM002 American Century Investment Management, Inc.
# US Power Quant Analyst : Oil and Gas Job Search Ltd
# Quantitative Researcher / Quantitative Research Analyst : Citadel Securities
# SEARCH- 1
# Commodities Quantitative Analyst : Selby Jennings
# Quantitative Analyst : AdHarmonics
# Consumer Finance Quantitative Analyst : Huntington
# Senior Associate - Quantitative Analyst : Capital One
# Quantitative Analyst : AlphaGrep
# Quant Analyst (PhD Required For This Role) (W2 Only / No C2C Available) : TEKsystems
# Quantitative Research Analyst : Brooklyn Investment Group
# Agency MBS Quantitative Analyst - Modeling and Research : Selby Jennings
# Quantitative Analyst (Remote) : Rainbook
# SEARCH- 2
# Global Quantitative Strategies | Quantitative Researcher : Citadel
# Quantitative Analyst : Next Step Systems – Recruiters for Information Technology Jobs
# Quantitative Strategy Developer- New Grad : Susquehanna International Group, LLP (SIG)
# Quantitative Fundamental Analyst : Selby Jennings
# Quantitative Trader preferred or Quantitative Analyst  REMOTE : Infinite Capital
# Quantitative Analyst : Demand Side Analytics
# Credit Quant : Hedge Fund
# Quantitative Research Analyst  - 2025 University Graduate (US) : Citadel Securities
# Equity Quantitative Research | Equity Model Research | Quantitative Researcher : Citadel
#
# ---------------
# AI Solutions Architect
# SEARCH- 0
# AI Solution Architect : Deloitte
# AI Solution Architect (USA) : Mistral AI
# Solution Architect, Artificial Intelligence : AARP
# AI/ML Solution Architect : Gunnison Consulting Group, Inc.
# AI Solution Architect (GCP)_Seattle : Photon
# Lead Specialist, AI Solutions Architect : KPMG US
# Solutions Architect | AI (Remote) : Trace3
# Artificial Intelligence (AI) Solutions Architect : Amivero
# AI Solution Architect – GPU : Advanced Micro Devices, Inc
# AI and ML Solutions Architect, Lead : 631 Booz Allen Hamilton_United States
# SEARCH- 1
# Senior Solution Architect (AI/ML) : Intellectt Inc
# Solutions Architect, AI : Lionbridge Technologies
# Senior Generative AI Solutions Architect. Job in Greenway LilyLifestyle Jobs : Amazon Web Services, Inc.
# Solutions Architect AI/ML - Remote - USA : FullStack Labs Inc.
# Senior Solution Architect (AI/ML) : Randstad USA
# Lead Specialist, AI Solutions Architect : KPMG
# Cloud Solution Architect - Data & AI : Microsoft
# Solutions Architect, Generative AI Specialist : 2100 NVIDIA USA
# Solutions Architect, AI : Lionbridge
# AI Solution Architect : Roehl Transport
# SEARCH- 2
# Principal Data AI Solutions Architect, AWS Industries, Telco : Amazon Web Services (AWS)
# AI Solution Architect / Senior AI Solution Architect (Pre-Sales) : C3 AI
# Senior AI Solutions Architect : Capital One
# Sr Solutions Architect, AI/ML Sustainability Lead, Energy - Products & Solutions : Amazon
# Senior Solution Architect AI ML : DS Technologies Inc
# Solutions Architect : Contextual AI
# Solution Architect : Iterate.ai
# Principal AI Solutions Architect : Wolters Kluwer
# Solutions Architect, AI : Lionbridge
# data and ai solutions architect - remote : kizan technologies
#
# ---------------
# Statistician
# SEARCH- 0
# Research Statistician (Scientist 2/3) : Los Alamos National Laboratory
# Statistician Operational (DOH/CHP #11348) : New Mexico Department of Health
# Statistician I : USC University of Southern California
# Sports Statistician : Genius Sports
# STATISTICIAN (OPERATIONS AND ADMINISTRATION) : US Defense Finance and Accounting Service
# Mathematical Statistician or Statistician (Data Scientist) - Direct Hire -12 Month Register- AMENDED : Internal Revenue Service
# Statistician : The Pennsylvania State University
# Survey Statistician - U.S. Census Bureau : U.S. Census Bureau
# Associate Statistician : WEST Inc
# Athletics Gameday Statistician : University of Denver
# SEARCH- 1
# Vital Statistics Services Statistician 2024-02440 : State of Wyoming
# PPM Data Scientist/Statistician I - CO : ProSidian Consulting
# Data Analytics / Bio Statistician / Statistics : Upwork
# Statistician - Semel Institute : UCLA Health Systems
# Biomedical Statistician – Open Rank (Instructor, Senior Instructor) : University of Colorado System
# Bayesian Statistician (Data Scientist) : ICR, Inc.
# Mathematical Statistician : U.S. Department of Transportation - Office of the Under Secretary for Policy
# Principal Statistician, Research Statistics : 1925 GlaxoSmithKline LLC
# Principal Sampling Statistician : Fors Marsh
# Principal Statistician - Staff Scientist, Biostatistics Projects : Planet Pharma
# SEARCH- 2
# Statistician, Clinical Services | Part-time | USD 25-30/hour : Upwork
# PhD Statistician : 001 The P&G Company
# Senior Statistician - Late Development (1 of 2) : Johnson & Johnson
# Statistician / Senior Survey Data Analyst : North Carolina Dept of Health and Human Services
# Public Notice for Direct Hire (STEM) - Mathematical Statistician : Public Health
# Statistician / Biostatistician / Bioinformatician : Vakula Technologies Inc
# Supervisory Mathematical Statistician : U.S. Department of the Treasury
# Public Health Statistician : Centers For Disease Control And Prevention
# Masters Statistician Intern : 100 Eli Lilly and Company
#
# ---------------
# Big Data Engineer
# SEARCH- 0
# Big Data Engineer : DISH
# Data Engineer (Eng 3) : TPX
# Sr Big Data Engineer Airflow and Oozie (GCP) : Rackspace Technology
# Senior Big Data Engineer - (Person360 & MDM) : Highmark Health
# Senior, Data Engineer, Big Data : Walmart Inc.
# Big Data Solution Engineer/Architect : Software Technology Inc.
# Big Data Engineer - Remote / Telecommute : Cynet Systems Inc
# Java Engineer (Big Data) : Quantix
# Big Data Engineer with strong Apache Spark : Lams Technology LLC
# Data Engineer : Lockheed Martin
# SEARCH- 1
# Big Data Engineer - Denver, CO : Georgia IT Inc.
# (Remote, International) Sr. Site Reliability Engineer, Big Data : PulsePoint
# FreeWheel- Data Engineer 3- Scala- Big Data- REMOTE : Comcast (CC) of Willow Grove
# Associate Principal Engineer (Big Data) : Nagarro
# Data Engineer : KBR
# Big Data Hadoop Developer : Damco Solutions
# Remote Digital Engineer - Big Data : Raft Company Website
# Sr Data Engineer : VIZIO, Inc.
# SEARCH- 2
# Big Data Engineering : Spectrum
# Data Engineer Lead : FedEx
# Data Engineer (Remote) : Irvine Technology Corporation
# Big Data Integration Engineer : 1805 KBR Wyle Services, LLC
# Data Engineer - Dallas, TX : Photon Group
# Software Engineer, System Scalability (US Remote Available) - 30786 : Splunk
# Big Data Engineer-Portland, OR : Georgia IT Inc.
# Data DevOps Engineer : VIZIO, Inc.
# Manager, Big Data Engineering : Pie Insurance
#
# ---------------
# Data Science Consultant
# SEARCH- 0
# Consultant - AI/ML Data Science Consulting, Health Segment - Campus 2025 : US101 Guidehouse Inc.
# Payments Fraud Analytics and Data Science Senior Consultant : Deloitte
# Data and Analytics Management Consultant : Point B
# AI/ML Health Data Science Consultant : US101 Guidehouse Inc.
# Data Scientist ::Primarily remote, 1-2 times a month onsite in Reston, VA : SmartIPlace
# Data Engineering Consultant : Blue Margin
# Data Reporting and Analytics Consultant : Kaiser Permanente
# Analytics Consultant : DATAECONOMY
# Data Analytics Consultant with S/4 HANA exp. (Remote) : RGP
# AI/ML Health Data Scientist Senior Consultant : US101 Guidehouse Inc.
# SEARCH- 1
# Data consultant : VirtualVocations
# Sr. Consultant  - Data Insights - Al/Analytics/ML : Capgemini Invent
# Structured Data Analytics, Managing Consultant (Legal) : Intelligent Discovery Sol
# Data Science Consultant : Deloitte
# FP&A Consultant with Data Science and Working Capital Expertise (Guidance Role) : Upwork
# Part Time Advisor - Data Analytics : Spinnaker Consulting Group, LLC
# Business Analytics Consultant : 631 Booz Allen Hamilton_United States
# Principal, Data Technology Consulting (Life Sciences) - Remote : EPAM Systems, Inc.
# Managing Consultant - Life Sciences - Data Science (Pharma & Biotech) : US101 Guidehouse Inc.
# SEARCH- 2
# Data Science Consultant : Deloitte
# Data Scientist 2 (ML analytics) : Prime Time Consulting LLC
# Consulting Director - Data Visualization, Data Science & Analytics (us) : Artefact
# Analytics Consultant : PhData
# Senior Data Analytics Consultant : Eide Bailly LLP
# Data Science Program Manager - SFL Scientific : Deloitte
# Manager- Analytics/ Data Science Specialist - Morris Plain New Jersey ,US : Genpact
# Data Science Senior Consultant : MetrixLab
# Sr People Analytics Consultant : Nielsen
#
# ---------------
# Automation Engineer
# SEARCH- 0
# PLM Teamcenter Automation Engineer : Talent Groups
# Automation Engineer : Insight Global
# Automation Engineer : Alfa Laval
# Senior Database Automation Engineer : CVS Health
# Automation Engineer : CPP- Euclid
# Automation Engineer : CCB Packaging Inc
# 2nd Shift Automation Engineer : Magna International Inc.
# Automation Engineer : The Mosaic Company
# CAD Flow Automation Engineer : Apple
# Automation Engineer - Power Systems : SEL Engineering Services, Inc.
# SEARCH- 1
# Senior Software Test Automation Engineer (SDET) : Cisco Meraki
# Automation Engineer : Thermo Fisher Scientific
# Automation Engineer - Level II : LVI Associates
# Automation Engineer : QuEST Global
# Electrical Automation Control Engineer : DSJ Global
# Senior Associate - Automation Test Engineer : New York Life Insurance Co
# Associate Specialist, Manufacturing Automation (On-site) : Merck
# Senior Process Automation Engineer : IPS-Integrated Project Services
# SEARCH- 2
# Senior QE Automation Engineer : Synechron
# Automation Engineer : Matthew Dutton Associates
# Automation Engineer : Everbrite, LLC
# CAD Flow Automation Engineer : Apple
# Automation Engineer : Career Crunch
# Senior Automation Engineer– Advanced Manufacturing (Hybrid) : Jacobs
# Test Automation Engineer : Ariel Partners
#
# ---------------
# Analytics Manager
# SEARCH- 0
# Analytics Manager, Business Intelligence and Reporting : Wal-Mart.com USA, LLC
# Director of Data & Analytics : Designs for Health
# Marketing Operations Analytics Manager : Broadcom Software
# Manager - Analytics & Insights - Data, AI, Solutions & Engineering : Baringa
# Credit Analytics Manager : Empower Finance
# Senior Manager, Analytics (Marketing Data Science) - Dallas, TX : Rise
# Quantitative Analytics Manager : Affirm
# Business Intelligence and Data Analytics Manager : InterEx Group
# Client Analytics Manager : Mozilla
# Marketing Analytics Manager : Alterra Mtn Co Shared Services Inc.
# SEARCH- 1
# Manager, Sales Analytics : Kao
# Marketing & Business Analytics Manager : Professional Assist Corporation
# Revenue Analytics & Enablement Manager : ACI Learning
# Senior Manager, Strategic Analytics : Universal Music Group
# Advanced Analytics Manager : Vanguard
# Content Analytics Manager - Vice President, Wealth Management : JPMorganChase
# Senior Manager, Fundraising Analytics : Wellesley College
# Manager, Advanced Analytics : Walmart Inc.
# Senior Sales Systems & Analytics Manager : Webflow
# SEARCH- 2
# Manager - Strategy & Advanced Business Analytics : Ally Financial
# Mergers and Acquisitions - Data Analytics Manager : Deloitte LLP
# Data Analytics Manager : GoodParty.org
# Client Quantitative Analytics Manager - AML : Bank of America
# GTM Analytics Manager : Chainguard
# Senior Analysis Manager : PlayStation
# Senior Project Manager - Data Analytics Solutions - Implementation - US Based - 100% Remote : CoEnterprise, LLC
# Data Engineering Manager, Analytics : Meta
# Quant Analytics Manager : 0100 KeyBank National Association
#
# ---------------
# Operations Research Analyst
# SEARCH- 0
# Operations Research Analyst : The MITRE Corporation
# Operations Research Analyst : U.S. Space Command
# OPERATIONS RESEARCH ANALYST : U.S. Department of the Navy
# Operations Research Analyst : 631 Booz Allen Hamilton_United States
# OPERATIONS RESEARCH ANALYST : AFELM US Space Command
# Operations Research Analysis SME : Systems Planning and Analysis, Inc.
# Operations Research Analyst : By Employers
# Operations Research Analyst, Junior : 631 Booz Allen Hamilton_United States
# OPERATIONS RESEARCH ANALYST : Air Force Inspection Agency (FO)
# Operations Research Analyst : SAIC
# SEARCH- 1
# Senior Operations Research Analyst : LinQuest
# Operations Research Systems Analyst - Open Rank (Mid-Senior Level)-ACL-Colorado Springs, CO-Onsite : Georgia Tech Research Institute
# Operations Research Analyst - IRS Recent Graduates Program : Internal Revenue Service
# Operations Research Analyst, Senior : 631 Booz Allen Hamilton_United States
# Operations Research Analyst : Leidos
# TMISS All-Source, CI, HUMINT, SIGINT & OSINT Operations Research Analysts, Planners, Screeners, and : Atlas Advisors LLC
# Operations Research Analyst - Hybrid : The Mitre Corporation
# Senior Operations Research Analyst / Predictive Modeler : LinQuest Corporation
# Operations Research Analyst at CDC : Centers For Disease Control And Prevention
# Operations Research Analyst III (Decision Support) : Systems Planning and Analysis
# SEARCH- 2
# Operations Research Systems Analyst : Jacobs
# Operations Research Analyst (All Source) (ORA-AS) – Targeting – DOD TS/SCI : DHPC TECHNOLOGIES, INC
# Senior Operations Research Analyst with Security Clearance : ClearanceJobs
# Sr. Principal Operations Research Analyst – Joint Warfighting Development : 0090 CORP-Corporate Office
# Space Control Research and Operational Support Analyst : SAIC
# OPERATIONS RESEARCH ANALYST (DATA SCIENTIST) : Agriculture, Office Of The Chief Financial Officer
# Operations Research Systems Analyst - Open Rank (Mid-Senior Leve with Security Clearance : ClearanceJobs
# Operations Research Analyst for Unmanned Aircraft Systems Integration : Federal Aviation Administration
# Senior Operations Research/Systems Analyst (SORSA) : US101 Guidehouse Inc.
# Operations Research Analyst Security Clearance : Department of the Air Force
#
# ---------------
# Robotics Engineer
# SEARCH- 0
# Robotics Engineer : John Charles Search
# Robotics Perception Engineer - remote US, freelance : 9am
# Principal Robotics Engineer - Bot Routing : Symbotic
# Manufacturing Robotics Automation Engineer, Staff : Lockheed Martin
# Robotics Engineer : Zeitview
# Robotics Engineer : BlueSpace
# Robotics Field Engineer : B Garage
# Robotics Engineer or Controls Engineer (Allen Bradley, Modicon, Fanuc E : TSNpartners
# GNC Robotics Engineer : E-Space
# Field Service Automation and Robotics Engineer : Hitachi Careers
# SEARCH- 1
# Robotics Engineer : Agile Staffing Groups
# Robotics Controls Engineer : 1X Technologies AS
# Summer 2025 Intern - Robotics Engineering - Florida : Stryker
# Robotics Engineer : Alpha Matrix
# Robotic Process Automation Lead : Simple Software Solutions Group, Inc
# Senior ML Engineer for Robotics & Autonomous Systems : The MITRE Corporation
# Process Automation and Robotics Engineer : KARL STORZ
# Robotics Engineers : Procter & Gamble
# Robotics Automation Engineer : Insight Global
# SEARCH- 2
# Staff Robotics Software Engineer : Slip Robotics
# Electrical Engineer - Autonomy & Robotics : DoorDash USA
# Robot Software Engineer : Tutor Intelligence
# Technical Sales Engineer – Drones and Robotics : Apellix
# Robotics Engineer : Alpha Matrix
# Robotics Engineer – San Jose, CA : Aesgs
# Robotics Software Engineer : Dexterity
#
# ---------------
# Bioinformatics Data Scientist
# SEARCH- 0
# Bioinformatics Data Scientist/Analyst : NIH-NCBI
# Bioinformatic Data Scientist : Protillion Biosciences
# Bioinformatics Data Scientist : Twist Bioscience
# Bioinformatics Analyst I - Genomic Data Scientist : Baylor College of Medicine
# Bioinformatics Data Scientist : Bestica Inc.
# Computational Biology Data Scientist : School of Medicine
# Genomic Data Scientist/ Bioinformatics : Zoetis
# Principal Scientist, Bioinformatics Data Science : Dyne Therapeutics
# Bioinformatician/Computational Analyst or Sr Bioinformatician/Computational Analyst, The Robert M. Berne Cardiovascular Research Center : UVA Health
# Bioinformatics Scientist II : Children’s Hospital of Philadelphia
# SEARCH- 1
# Bioinformatics Data Scientist/Analyst : NIH-NCBI
# Bioinformatics Data Scientist : Jobot
# Data Scientist in Bioinformatics and Neuroscience : Chen Lab @ Boston University
# Bioinformatics Data Scientist Developer : MyGradJob
# Computational Science Analyst I - Bioinformatics Shared Resource (BSR) : Cold Spring Harbor Laboratory (CSHL)
# Bioinformatics Data Scientist : Clear Point Consultants
# Research Scientist or Sr Research Scientist in Bioinformatics/Computational Biology, The Robert M. Berne Cardiovascular Research Center : UVA Health
# Bioinformatics Data Scientist (Systems Biology and Data Visualization) : SoftWash Systems - Advantage SoftWash
# Senior Bioinformatics Scientist II : Abbott Laboratories
# Bioinformatics Data Scientist : Jobot
# SEARCH- 2
# Bioinformatics Specialist (The Data-Driven Biologist) : Unreal Gigs
# Bioinformatics Analyst : University of Pittsburgh
# Senior Data Scientist (Biostatistics and Bioinformatics Core (BBC) : University of Pennsylvania
# Biomedical Data Science / Bioinformatics | Python, R, SQL | Clearance Req. | Washington DC : Deloitte
# Group Lead – Bioinformatics & Data Analysis : The MITRE Corporation
# Sr. Bioinformatics Scientist : Catalytic Data Science
# Bioinformatics Senior R Engineer (Clinical Data Scientist) : EPAM
# Bioinformatics Data scientist - Foster City, California : Cube Hub Inc.
# Bioinformatics Scientist : Compugen USA
#
# ---------------
# Financial Data Scientist
# SEARCH- 0
# Principal Data Scientist : Self Financial
# Senior Data Scientist, Business Finance : StackAdapt
# Staff Data Scientist - Remote : Empower Finance
# Data Scientist, Financial Risk : Stripe
# Senior Financial Analyst- Data Analytics : McDonald's Corporation
# Sr. Financial Analyst, Data Scientist : Pharmavite
# Associate- Finance Data Analytics : Eli Lilly and Company
# Manager, Data Scientist : Charles Schwab Inc.
# Data Science Senior Manager - Financial Services : 1000 Accenture LLP Company
# Data Scientist Senior Associate : JPMorgan Chase
# SEARCH- 1
# Investment Data Scientist : Sparc The World
# Data Scientist Senior - Fraud Model Management : USAA - United Services Automobile Association
# FP&A Consultant with Data Science and Working Capital Expertise (Guidance Role) : Upwork
# Director - Data Science : Edward Jones
# Vice President, Data Science Lead - PGIM : 032 PGIM, Inc.
# Payments Fraud Analytics and Data Science Senior Consul : Deloitte
# Financial Crimes, Data Scientist - Exp Assoc (Financial Services) : PwC
# Payments Fraud Analytics and Data Science Senior Consultant : Deloitte
# Lead Data Scientist, Finance : Updater
# 2025 Fall Associate- Economics and Data Analytics : Berkeley Research Group (BRG)
# SEARCH- 2
# PPM Data Scientist/Statistician I - CO : ProSidian Consulting
# Business Data Analyst for Financial Modeling Systems : Intelagile
# Data Analyst - (Banking) : Nesco Resource
# Data Scientist Co-Op – Construction & Engineering Global Industry Unit : Oracle
# Data Scientist/Analyst (India) : PayZen
# Counterparty Data Analyst : Insight Global
# Decision science analyst : USAA
# Data Analyst 4 in North Chesterfield VA : Syntricate Technologies
# Data Scientist – Risk Analysis and Develop Machine Learning Custom Scoring Model for Underwriting : Upwork
# Software Engineering Manager- Machine Learning Infrastructure : Plaid Inc.
#
# ---------------
# Customer Insights Analyst
# SEARCH- 0
# Lead Customer Insights Analyst : AFMIC American Family Mutual Insurance Company, S.I.
# Senior Analyst- Customer Insights and Programs : Colorado Springs Utilities
# Analyst Customer Loyalty & Insights : Walgreens
# Consumer/Shopper Insights Analyst (Hybrid- Camden, NJ) : Circana
# Wireless Insights Analyst : DISH
# Senior Analyst Consumer Insights : Nestlé
# Customer Insights Associate Director : Verizon
# Customer Insights Coordinator : City of Charlotte
# Customer Insights and performance Analyst for a food delivery platform in UAE : Upwork
# Customer Analytics Analyst : Funding Circle
# SEARCH- 1
# Contact and Conversation Insights Analyst Lead : DISH
# Sr Customer Insights Analyst : Xcel Energy
# Residential Consumer Insights Specialist : Clovity
# Insight Analyst : Antenna
# Senior CML Data & Insights Analyst : The Huntington National Bank
# Customer Experience Analyst : SambaSafety
# Senior Web Data Analyst : Sand Cherry Associates
# Senior Data Analyst - Customer Service : BetMGM LLC
# SEARCH- 2
# Senior Data Analyst, Customer Experience Platform : Toast
# Sr. Complaint Management & Customer Insights Manager - Remote : Flagstar Bank, N.A.
# Data Analyst, Customer Support : Scribd
# Seeking Consumer Analytics and Sales Data : Upwork
# Senior Solutions Analyst, Analytics Customer Excellence(OASE) : Oracle
# Data analyst customer science : Popular Community Bank
# Senior Analytics & Insights Associate : 1 Vizient, Inc.
# Consumer Insights Lead : Silgan Dispensing
# Senior Analyst – Marketing Insights : Walgreens
# Insights Manager : BEHAVIORALLY INC
#
# ---------------
# Marketing Data Analyst
# SEARCH- 0
# Sr Marketing Data Analyst - Spectrum Reach : SPECTRUM
# REMOTE: Marketing Data Analyst Job at Marrina Decisions in Wisconsin : Marrina Decisions
# Resource Label Group LLC is hiring: Marketing Data Analyst in Longmont : Resource Label Group
# Right Side Up Is Hiring Marketing Data Analyst In Bee Cave (Remote) : Right Side Up
# Data Analyst (Marketing) : Techint Labs
# Marketing Data Analyst : 100
# Sr Marketing Data Analyst - Spectrum Reach : Spectrum
# Marketing Data Analyst - Hybrid : Bosch
# Marketing Data Analyst – B2B High Tech (Remote) : Stage 4 Solutions Inc
# Marketing Data Analyst I (Onsite) : 005 Southwest Business Corporation
# SEARCH- 1
# Freelance Data Analyst (Marketing Data Specialist) : Upwork
# Data Analyst, Marketing : Cribl
# CRM Data Analyst, Global Marketing, LHH : LHH (Global)
# Senior Marketing Analyst (Remote) : Yelp
# Marketing Data Analyst, Hybrid: NYC or Maryland based : Crédito y Caución Atradius
# Data Analyst (Marketing) (f/m/d) : IONOS EN
# Marketing Data Analyst : Amiseq Inc.
# Staff Data Analyst, Marketing Science : 105 TechStyle, Inc.
# Senior Data Analyst, Marketing Analytics : Athletic
# SEARCH- 2
# Digital Marketing Data Analyst : Upwork
# Marketing Data Analytics Specialist : Prosci
# Marketing Analyst : Visa
# Senior Manager, Analytics (Marketing Data Science) - Dallas, TX : Rise
# Performance Marketing Analyst : Elsmere Education
# Marketing Data Analyst Needed to Drive Insights : Upwork
# Sr. Analyst, Marketing Analytics (Web / App) : Vail Resorts
# Senior Marketing Analyst, Web and Experimentation : Klaviyo
# Database Marketing Analyst : Vail Resorts
# Marketing Data Science Manager : Empower
#
# ---------------
# Data Strategy Manager
# SEARCH- 0
# Manager, Data Strategy & Privacy : About, Inc.
# Data Governance & Data Strategy Manager : LifeScale Analytics
# Senior Manager, Data Strategy : Fidelity Investments
# Senior Data Strategy & Architecture Manager : Barry Callebaut
# Strategic Initiatives and Data Operations Manager : Naropa University
# Director, Data Strategy and Governance : Fidelity Investments
# Manager - Analytics and Data Strategy : 2001 Alere Inc.
# Associate Director, Data Strategy : Wpromote
# Head of Data Strategy : Confidential
# Director of Data & Analytics : Designs for Health
# SEARCH- 1
# Senior Manager, Strategy And Business Development (data Centers) : Intersect Power
# Director of Data Content and Strategy : LexisNexis Risk Solutions
# Senior Director, Advancement Data Strategy and Insights : University of Chicago
# Data Governance & Strategy Lead : Blend360
# Business Development Manager - Data Partnerships : Paychex
# Director – Data Strategy & Analytics - Healthcare : Kepler Group
# Director, Analytics and Insights : Caring
# Utilities AI Value Strategy Manager : Accenture
# Corporate Strategy Data Analyst - 1756803 : IN2U
# SEARCH- 2
# Data Governance Program Manager : Mitsubishi Chemical Group
# Senior Associate, Data Strategy, Marketing Technology : DoorDash
# Director, Business Intelligence Team : 100 Miami University
# Director of Data Analytics and Strategy : SEIU Local 1
# Data Strategy consultant : VRK IT Vision Inc.
# Private Markets Data Strategy Analyst : 4100 NB Alternatives Advisers LLC
# Digital Marketing Data & Analytics Manager : IRIS Software Group
# Senior Product Manager: Marketing Data Products & Insights : Autodesk
# (USA) Director, Data Analytics : Walmart Inc.
#
# ---------------
# Cloud AI Engineer
# SEARCH- 0
# Cloud AI Engineer : TechnoServe Inc.
# Cloud Engineer, AI/ML, Professional Services, Google Cloud : Google
# AWS Cloud AI Engineer : Algobrain
# Senior Machine Learning Engineer – Cloud AI Platform : iVisa
# Software Engineer, AI Tools : Salesforce, Inc.
# AI Cloud Engineering Manager : Lambda
# Senior Software Engineer (Machine Learning & Infrastructure), Acrobat AI Assistant : Adobe
# Engineer generative : Google Inc.
# Azure AI Engineer : Eliassen Group
# Principal Technologist for AI, Cloud and AI Innovation Team : Amazon Web Services (AWS)
# SEARCH- 1
# DevOps Engineer - AI | Experienced Hire : Susquehanna International Group, LLP (SIG)
# Azure AI Engineer [Capital Markets/ Investment Backing background] : Synechron
# Sr. AI Platform Software Architect : Qualcomm
# Sr Machine Learning Engineer, Computer Vision, ML Data Platform : Adobe
# Software Engineer (Framework - Solutions), Ai & Data Platforms : Apple
# SEARCH- 2
# Ai ml architect : Highmark Health
# AI Solution Architect : Deloitte
# AI/ML Infrastructure Engineer : Candidate Portal
# Python and Kubernetes Software Engineer - Data, AI/ML & Analytics : Canonical - Jobs
# Enterprise - Senior AI/ML Software Engineer - Java, Python, Cloud : Erias Ventures, LLC
# Principal Member of Technical Staff - AI/ML Search Infrastructure : Oracle
# Principal Engineer, Cloud ML Compute Services : Google
# Technical Curriculum Developer III, AI/ML, Cloud Learning : Google
# Senior Data Engineer - AI Platform : Lenovo
#
# ---------------
# Computational Scientist
# SEARCH- 0
# Computational Scientist, Large Scale Simulation : Oak Ridge National Laboratory
# Computational Scientist BIOHPC : UT Southwestern Medical Center
# Computational Scientist | Miller Brain Observatory : Rockefeller University
# Computational Scientist (Scientist 2/3) : Los Alamos National Laboratory
# Computational Research Scientist II, Physiological Data Modeling (Hybrid) : The Henry M. Jackson Foundation for the Advancement of Military Medicine
# Computational Scientist : Roswell Park Comprehensive Cancer Center
# Computational Scientist (NWS 00721) : North Wind Group
# Computational Scientist : Idaho National Laboratory
# Senior Computational Research Scientist : St. Jude Children's Research Hospital
# Computational Scientist : AWE plc
# SEARCH- 1
# Senior Scientist - Computational Materials Science : Pfizer
# Scientist I - Computational Chemistry Core : Dana-Farber Cancer Institute
# Senior Scientist, Computational Biology / Toxicology : Merck
# Computational Research Scientist II, Toxicology (Hybrid) : The Henry M. Jackson Foundation for the Advancement of Military Medicine
# Computational Scientist in Single Cell Genomics : New York Genome Center
# Principal Research Scientist I, Computational Chemistry Platform : AbbVie
# Monte Carlo Computational Scientist/Developer (Scientist 2/3) : Los Alamos National Laboratory
# HPC Systems Scientist (Remote Eligible) : Oak Ridge National Laboratory
# Computational Scientist, Machine Learning : Altos Labs
# Principal Scientist, Early Translational Computational Science for Immunology, Cardiovascular and Neurology : Bristol Myers Squibb
# SEARCH- 2
# Computational Research Scientist II - Bone/Musculoskeletal Biomechanics (Hybrid) : The Henry M. Jackson Foundation for the Advancement of Military Medicine
# Computational Science Manager - Mitra Lab : Cold Spring Harbor Laboratory (CSHL)
# Computational Scientist - Proteomics : Broad Institute
# Computational Scientist in Neuroimaging and Data Analysis : Rockefeller University
# Computational Scientist - Cancer Immunogenomics : Planet Pharma
# Senior Computational Scientist : ViewRay Systems, Inc.
# Computational Research Scientist I : The Henry M. Jackson Foundation for the Advancement of Military Medicine
#
# ---------------
# Fraud Detection Specialist
# SEARCH- 0
# Customer Service in Fraud (Hybrid) - Starting at $20.05/HR : Citibank, N.A.
# Fraud Investigator / Recovery Specialist : Montezuma County Government
# Sr Fraud Analyst II (Fraud Detection - Digital) : Bank of America
# Fraud Investigation Analyst (Disputes) : Self Financial
# Fraud Analytics and Innovation Senior Analyst - Fraud Detection Strategies : Bank of America
# Investigative Mgmt Analyst/Fraud Detection Anlst/Body Worn Camera Coord-Direct Hire-12 Month Roster : U.S. Department of the Treasury
# Fraud Data Analyst : EchoStar
# Fraud Operations Analyst : DISH
# Fraud Prevention Specialist : Stateside
# Manager, Fraud Prevention and Detection : USAA
# SEARCH- 1
# ERROR FOUND IN SEARCH
# No results found for 'Fraud Detection Specialist' on SEARCH- 1.
#
# ---------------
# Risk Analyst
# SEARCH- 0
# Third Party Risk Analyst : TMobile
# Counterparty and Derivatives Risk Analyst : Vanguard Careers
# Risk Analyst I : Provident Bank
# Sr Analyst,Security Risk Mgt : CVS Health
# Senior Technology Risk Analyst : Mastercard
# Sr. Treasury Risk Analyst (Hybrid) : TEKsystems
# Senior ORM Risk Analyst - Hybrid/Remote : comerica
# Risk Analyst II/Risk Analyst III : First Citizens Bank
# Information Security Risk Analyst : University of California, Irvine
# Risk Analyst (Finance) : Suncoast Credit Union
# SEARCH- 1
# Associate Market Risk Analyst : Xcel Energy
# Mortgage GRC/Risk Analyst : Convergenz
# Pricing Risk Analyst : Honda
# Risk Analyst/Manager : Bowhead
# Risk Analyst III - Operational Risk Events Program : First Citizens Bank
# Quantitative Risk Analyst : Farm Credit East
# Analyst Financial Risk Management : Uber
# Risk Analyst Lead-Payments : USAA
# Risk Management Analyst : City of Durham
# SEARCH- 2
# Senior Financial Risk Analyst : LE001 Federal Home Loan Bank of New York
# Jr. Risk Analyst : Royal Business Bank
# Risk Analyst : Dollar Tree
# Risk Analyst - Treasury. Job in Youngsville LilyLifestyle Jobs : First Citizens Bank
# Regulatory Risk Analyst : Oxford Bank
# Information Security Risk Analyst : Booz Allen Hamilton
# Private Equity Risk Analyst at Top Investment Company, Orlando, FL : JRG Partners LLC
# Risk Analyst : Extreme Event Solutions
# Data Analyst - (HR Risk Team) : NESCO Inc
# Director – Quantitative Risk Analyst : Concero
#
# ---------------
# Data Architect
# SEARCH- 0
# Data architect : Capital One
# Data Architect : Arkansas Department of Workforce Services
# Data Architect : Virginia Tech
# Sr Data Architect I : Staples, Inc.
# Principal Data Architect (Intelligence Center) : The MITRE Corporation
# Principal Data Architect : Disney Experiences
# Senior Data Architect : Beacon Hill
# Data Architect - Industrials & Energy Sector - Senior - Consulting - Location Open : EY
# Senior Cloud Data Solutions Architect : Truist Bank
# Data Architect : Clean Harbors
# SEARCH- 1
# Data Architect : Pantex
# Senior Data Architect : Genworth
# AWS Data Architect : SAGE IT
# Senior Data Architect, Results Data Exchange : IDEXX
# Lead Data Architect : NiSource Careers
# Digital Business & Data Architect, ONSITE, AZ or TX : RTX
# Data Architect (Semantic and Graph Technologies) : Equifax
# Lead Enterprise Data Architect : White Cap
# Federal Enterprise Data Architect (Top Secret Required) : Deloitte
# Data Architect : Birlasoft
# SEARCH- 2
# ERROR FOUND IN SEARCH
# No results found for 'Data Architect' on SEARCH- 2.
